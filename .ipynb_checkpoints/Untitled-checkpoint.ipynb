# %% [markdown]
# # Scraping Exam Info from the SOA

# %% [markdown]
# ## Download Results Files and Packages
# Information for exam passers in 2018 is available here:
# https://www.soa.org/education/general-info/exam-results/edu-exam-results-archive.aspx
#
# We download packages for reading pdfs, using regular expressions, and interacting with our file directories.

# %%
import PyPDF2
import re
import os

# %% [markdown]
# ## Extracting Names from a PDF
# There are a lot of files to extract the names from. First lets figure out how to do a single file then we will work on iterating over all of the files.
#
# There are multiple pages so we iterate through the pages using a regular expression to extract all the names on each page. The names come as an ordered list so we use a regular expression to pick up text starting with a number and a period and ending before we hit any more numbers.

# %%
#Regular expression for extracting names.
#A simpler regex will break for people with numbers in their names (example: "3rd")
regexName = re.compile(r'\d+\.\s[^,]+,\s[^0-9]+')

def scrapeNames(path):
    #Use pdf reader
    pdfFileObj=open(path, "rb")
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    #Iterate over pages and extract all names
    maxPage = pdfReader.numPages
    allNames = []
    for pageNum in range(0,maxPage):
        pageText = pdfReader.getPage(pageNum).extractText()
        allNames += regexName.findall(pageText)
    return allNames

#Extract names and examine output.
rawNames = scrapeNames("./edu-2019-03-p-names-3tgjhu7.pdf") #This is from the downloaded zip.
rawNames
# Out:
# ['1. Abbas, Fizza  \n ',
#  '2. Abdul Aziz, Talha  \n ',
#  '3. Ackerman, Samuel  \n ',
#  '4. Acosta, Ana  \n ',
#  '5. Acri, Sierra  \n ',
#  '6. Adamic, Haley Michelle \n ',
#  '7. Adamo, Anthony  \n ',
#  '8. Adeagbo, Oluwakemi  \n ',
#  '9. Adlan, Anis Syafiqah  \n ',
#  '10. Agrawal, Yogesh  \n ',
#  '11. Aguayo Dupin, Nicolas Antonio  \n ',
#  '12. Aguirre, Andrew  \n ',
#  '13. Alam, Farheen Kabir \n ',
#  '14. Alaskar, Ruba  \n ',
#  '15. Albano, Carl  \n ',
#  '16. Alberto, Janette  \n ',
#  '17. Al-Burti, Aliaa  \n ',
#  '18. Aldaoud, Abir  \n ',
#  '19. Alfallaj, Abdulkarim  \n ',
#  '20. Ali, Nade  \n ',
#  '21. Allen, Asrielle  \n ',
#  '22. Alqahtani, Reem Saleh \n ',
#  '23. Alsayel, Abdulrhman  \n ',
#  '24. Alvarado, John Renz  \n ',
#  '25. Amstislavskiy\n, Eric  \n ',
#  '26. Anderson, Lance  \n ',
#  '27. Anderson, Michael  \n ',
#  '28. Armanious, Miriam  \n ',
#  '29. Asavatheputhai, Pongsathorn  \n ',
#  '30. Aselisewine, Wisdom  \n ',
#  '31. Astiazaran, Juan  \n ',
#  '32. Attara, Florence  \n ',
#  '33. Aun, Syed  \n ',
#  '34. Avila, Monica  \n ',
#  '35. Awotwe, Emmanuel  \n ',
#  '36. Ayers, Megan  \n ',
#  '37. Bahr, Anna  \n ',
#  '38. Bahr, Spencer  \n ',
#  '39. Baillie, Madeline  \n ',
#  '40. Bajsicka, Weronika  \n ',
#  '41. Bakri, Nada  \n ',
#  '42. Baraka, Mira  \n ',
#  '43. Barash, Jacqueline  \n ',
#  '44. Barman, Tyler  \n ',
#  '45. Barrett, Brooke  \n ',
#  '46. Bartlett, Connor  \n ',
#  '47. Basquez, Nichol  \n ',
#  '48. Bautista, Ivan Christian  \n ',
#  '49. Bechhofer, Samson  \n ',
#  '50. Behrend, Whitney  \n ',
#  '51. Bellefeuille, Vincent  \n ',
#  '52. Bend\ner, Luke  \n ',
#  '53. Bennett, Bryan  \n ',
#  '54. Berger, Rivka  \n ',
#  '55. Best, Abigail  \n ',
#  '56. Bhula, Pooja  \n ',
#  '57. Bidlingmaier, Robert  \n ',
#  '58. Birkicht, Taleah  \n ',
#  '59. Blair, Derek  \n ',
#  '60. Blair, Maria  \n ',
#  '61. Blake, David  \n ',
#  '62. Blomster, Daniel  \n ',
#  '63. Blyuss, Nicole  \n ',
#  '64. Boamah, Emmanuel  \n ',
#  '65. Bogdanis, David  \n ',
#  '66. Bonneville, Daniel  \n ',
#  '67. Boontem, Arissara  \n ',
#  '68. Brackey, Adrienne  \n ',
#  '69. Brand, Franklin\n-Xavier  \n ',
#  '70. Braun, Brittnee  \n ',
#  '71. Brauns, Kaleigh  \n ',
#  '72. Brumley, Austin  \n ',
#  '73. Buchanan\n-Boothe, Shawntoll  \n ',
#  '74. Burlingame, James  \n ',
#  '75. Burns, Jackson  \n ',
#  '76. Butsaraphuphuengpham, Sitiphon  \n ',
#  '77. Cahill, Joseph A. \n ',
#  '78. Cai, Wenting  \n ',
#  '79. Cain\n, Levi  \n ',
#  '80. Cairney, Zachary  \n ',
#  '81. Cairo, Kevin  \n ',
#  '82. Cao, Mengya  \n ',
#  '83. Cao, Siqing  \n ',
#  '84. Cappaert, Mark  \n ',
#  '85. Carlstrom, Joseph  \n ',
#  '86. Chahalis, Taylor  \n ',
#  '87. Chan, Jack  \n ',
#  '88. Chan, Kyle  \n ',
#  '89. Chang, Yu\n-Feng  \n ',
#  '90. Chao, Guo An  \n ',
#  '91. Chavez Quinonez, Daniel Rafael  \n ',
#  '92. Chen, Chris  \n ',
#  '93. Chen, Hanqi  \n ',
#  '94. Chen, I\n-Chun  \n ',
#  '95. Chen, Jian\n-He  \n ',
#  '96. Chen, Jinyan  \n ',
#  '97. Chen, Kaini  \n ',
#  '98. Chen, Lei  \n ',
#  '99. Chen, Mengfan  \n ',
#  '100. Chen, Po Jui  \n ',
#  '101. Chen, Qian  \n ',
#  '102. Chen, Siyuan  \n ',
#  '103. Chen, Wan\n-Hsuan  \n ',
#  '104. Chen, Wilton  \n ',
#  '105. Chen, Xiaodi  \n ',
#  '106. Chen, Xudong  \n ',
#  '107. Chen, Yanzhu  \n ',
#  '108. Chen, Yitong  \n ',
#  '109. Cheng, Lam  \n ',
#  '110. Cho, Sangwook  \n ',
#  '111. Cho\ni, Jungyoon  \n ',
#  '112. Chong, Kar Ken  \n ',
#  '113. Chu, Calvin  \n ',
#  '114. Chueaphet, Sasitorn  \n ',
#  '115. Colabatistto, Kristen  \n ',
#  '116. Colegrove, Dale  \n ',
#  '117. Collado, Christian Kenneth  \n ',
#  '118. Cooper, Bryan  \n ',
#  '119. Corbeil, Alexandre  \n ',
#  '120. Cornett, Julie  \n ',
#  '121. Coutinho, Seth  \n ',
#  '122. Coyne, John  \n ',
#  '123. Craig, Andrew  \n ',
#  '124. Crow, Connor  \n ',
#  '125. Cruse, Robert  II,\n ',
#  '126. Curtis, Devon  \n ',
#  '127. Cushing, Jacob  \n ',
#  '128. Daniele\n-Dinndorf, Anna Louise \n ',
#  '129. Daniels, Walter  \n ',
#  '130. Danzer, Craig  \n ',
#  '131. Dao Thi Ha, Phuong  \n ',
#  '132. Davies, Steven  \n ',
#  '133. de Castro Perez, Ines  \n ',
#  '134. Deaver, Karen  \n ',
#  '135. DeBenedictis, Nikolette  \n ',
#  '136. DeBlieux, Jefferson  V,\n ',
#  '137. Deen, Stanl\ney  \n ',
#  '138. DelGrande, Sarah  \n ',
#  '139. Deng, Haohua  \n ',
#  '140. Desai, Hely  \n ',
#  '141. Dick, Jake  \n ',
#  '142. DiDio, Kayla\n-Mae  \n ',
#  '143. Dimitrov, Martin  \n ',
#  '144. Ding, Yijing  \n ',
#  '145. Ding, Ying  \n ',
#  '146. Dockter, Brianna  \n ',
#  '147. Dokmanovich, Emma  \n ',
#  '148. Dominique, Yan  \n ',
#  '149. Dona, Michele  \n ',
#  '150. Donald, Stephen  \n ',
#  '151. Dong, Guoxiu  \n ',
#  '152. Dong, Jiayu  \n ',
#  '153. Dong, Wenli  \n ',
#  '154. Dooley, Meredith  \n ',
#  '155. Dougherty, Steven  \n ',
#  '156. Dowling, Matthew Patrick \n ',
#  '157. Doyle, Andrew  \n ',
#  '158. Dozer, Grant  \n ',
#  '159. Drewes, Will  \n ',
#  '160. Du, Noah  \n ',
#  '161. Du, Qingyang  \n ',
#  '162. Duan, Bingjie  \n ',
#  '163. Dulashko, Tatiana  \n ',
#  '164. Eckardt, Benjamin  \n ',
#  '165. Edwards, Brandon  \n ',
#  '166. Emerick, Brooke  \n ',
#  '167. Eoff, Jared \n  ',
#  '168. Eriksson, Jake  \n ',
#  '169. Ernster, John  \n ',
#  '170. Erquiaga, Sebastian  \n ',
#  '171. Esparza, Miranda  \n ',
#  '172. Fan, Jiayue  \n ',
#  '173. Fan, Shiyu  \n ',
#  '174. Fan, Yao  \n ',
#  '175. Fan, Yuqian  \n ',
#  '176. Fang, Yuping  \n ',
#  '177. Fang, Zheng  \n ',
#  '178. Fantevi, Andrews  \n ',
#  '179. Farhadova, Aisha  \n ',
#  '180. Farooqi, Bisma Narmeen  \n ',
#  '181. Fehrman, Karli  \n ',
#  '182. Fenghua, Liu  \n ',
#  '183. Fernandez, Christie Anne  \n ',
#  '184. Fettich, William  \n ',
#  '185. Fisher, Thomas  \n ',
#  '186. Fitzpatrick, Brendan  \n ',
#  '187. Flores, Homero  \n ',
#  '188. Frydryk, Paul  \n ',
#  '189. Fu, Wanglu  \n ',
#  '190. Fujita, Suguru  \n ',
#  '191. Fuller, Benjamin  \n ',
#  '192. Fung, Jonathan  \n ',
#  '193. Gai, Yanan  \n ',
#  '194. Gallis, John  \n ',
#  '195. Gambale, John  \n ',
#  '196. Gao, Congyi  \n ',
#  '197. Gao, Fan  \n ',
#  '198. Gao, Lei  \n ',
#  '199. Gao, Tianyou  \n ',
#  '200. Gao, Xiao  \n ',
#  '201. Garcia, Ernesto  \n ',
#  '202. Garcia, Tatiana  \n ',
#  '203. Gatpolintan, Danielle Ann  \n ',
#  '204. Geiger, Katherine  \n ',
#  '205. Geng, Guangzhen  \n ',
#  '206. Geng, Lijie  \n ',
#  '207. Gentry, Nicholas  \n ',
#  '208. Gestetner, Joseph  \n ',
#  '209. Gillespie, Robert  \n ',
#  '210. Gillette, David  \n ',
#  '211. Gipson, Danita  \n ',
#  '212. Giuffre, Anthony  \n ',
#  '213. Gleeson\n-Rosson, Brian  \n ',
#  '214. Go, Inmu  \n ',
#  '215. Goel, Jaidev  \n ',
#  '216. Goff, Dustin  \n ',
#  '217. Goh, Ka Mun  \n ',
#  '218. Goh, Pei Shan  \n ',
#  '219. Goldberg, Matisyahu  \n ',
#  '220. Gonzalez Orta, Rodolfo  \n ',
#  '221. Goto, Yosuke  \n ',
#  '222. Grainey, Elizabeth  \n ',
#  '223. Grueneberg, Jeffrey  \n ',
#  '224. Gu, Junwen  \n ',
#  '225. Guan, Peijun  \n ',
#  '226. Guan, Yan\njia (Kyle)  \n ',
#  '227. Gundersen, John  \n ',
#  '228. Guo, Bingcui  \n ',
#  '229. Guo, Caiyun  \n ',
#  '230. Guo, Chenxi  \n ',
#  '231. Guo, Keli  \n ',
#  '232. Ha, Ngoc\n-Kim  \n ',
#  '233. Haight, Russ  \n ',
#  '234. Hallenbeck, Elise  \n ',
#  '235. Hanks\n-Witaszek, Elise  \n ',
#  '236. Hansen, Johanna  \n ',
#  '237. Hanyin, Mao  \n ',
#  '238. Hao, Yi  \n ',
#  '239. Hao, Yuewei  \n ',
#  '240. Harding, Chris  \n ',
#  '241. Harnden, Matthew Tyler \n ',
#  '242. Hasija, Anika  \n ',
#  '243. Hawkins, Jordan  \n ',
#  '244. Hawkins, William  \n ',
#  '245. He, Daijie  \n ',
#  '246. He, Fou  \n ',
#  '247. He, Yunbo  \n ',
#  '248. Heatherman, Bo  \n ',
#  '249. Heimbrock, Simon  \n ',
#  '250. Hendricks, Mercedes  \n ',
#  '251. Hernandez, Jesus Octavio Rodriguez \n ',
#  '252. Hillman, Sean  \n ',
#  '253. Hippisley, Joseph  \n ',
#  '254. Hirsch, Jeremy\n   ',
#  '255. Hollman, Christopher  \n ',
#  '256. Holton, James  \n ',
#  '257. Honiss, Zachary  \n ',
#  '258. Hooley, David  \n ',
#  '259. Hott, Harrison  \n ',
#  '260. How Yee Chong, Jordan Dean  \n ',
#  '261. Hsiao, Yu\n-Tyng  \n ',
#  '262. Hsin, Pei\n-Ni  \n ',
#  '263. Hsu, Kui Yuan  \n ',
#  '264. Hu, Clarence  \n ',
#  '265. Hu, Hongda  \n ',
#  '266. Hu, Jingning  \n ',
#  '267. Hu, Xiaoyu  \n ',
#  '268. Hu, Xinqi  \n ',
#  '269. Hua, Vy Ngoc Anh  \n ',
#  '270. Huang, Haichen  \n ',
#  '271. Huang, Qianxin  \n ',
#  '272. Huang, Raymond  \n ',
#  '273. Huang, Shaowei  \n ',
#  '274. Huang, Xian Ting  \n ',
#  '275. Huang, Xinhui  \n ',
#  '276. Huang, Yu\n-Hsiang  \n ',
#  '277. Huang, Yuqi  \n ',
#  '278. Huang, Yuting  \n ',
#  '279. Hue, Michael  \n ',
#  '280. Huggins, Alkin  \n ',
#  '281. Huixin, Eu  \n ',
#  '282. Hung, Samantha  \n ',
#  '283. Huo, Siqing  \n ',
#  '284. Hupp, Zac\nhary  \n ',
#  '285. Hussain, Syed Zohaib \n ',
#  '286. Huynh, Son  \n ',
#  '287. Huysman, Liam  \n ',
#  '288. Hyland, Brittany  \n ',
#  '289. Hyun, Juhong  \n ',
#  '290. Ibiribigbe, Saidat  \n ',
#  '291. Irshad, Umar  \n ',
#  '292. Ishida, Robyn  \n ',
#  '293. Iwanicka, Sylwia  \n ',
#  '294. Jackman, Adriana  \n ',
#  '295. Jackman, Calen  \n ',
#  '296. Jackson, Benjamin  \n ',
#  '297. Jakkraphobyothin, Ponthakorn  \n ',
#  '298. James, Lincoln  \n ',
#  '299. Jang, Jinho  \n ',
#  '300. Jensen, Peter  \n ',
#  '301. Jeong, Myeonghwan  \n ',
#  '302. Jepsen, Alison  \n ',
#  '303. Jepsen, Jeremiah  \n ',
#  '304. Jia Jin, Chua  \n ',
#  '305. Jiang, Shuyue  \n ',
#  '306. Jiang, Tongyao  \n ',
#  '307. Jiang, Weiyi  \n ',
#  '308. Jiang, Yuzhaoran  \n ',
#  '309. Jin, Jiachen  \n ',
#  '310. Jing, Liqing  \n ',
#  '311. Jochem, Josef  \n ',
#  '312. John, Stanley  \n ',
#  '313. Johnston\n, Lucas  \n ',
#  '314. Jones, Erica  \n ',
#  '315. Jung, Heedo  \n ',
#  '316. Kabore, Elisee  \n ',
#  '317. Kacmarski, Michaela  \n ',
#  '318. Kah Foong, Edmund Hong  \n ',
#  '319. Kaixiong, Huang  \n ',
#  '320. Kalthoff, Jenna  \n ',
#  '321. Kamaraj, Suganthi  \n ',
#  '322. Kan, Jun Yang  \n ',
#  '323. Kane, Matthew  \n ',
#  '324. Kang, Emily  \n ',
#  '325. Kary, Mack  \n ',
#  '326. Kavanaugh, Luke  \n ',
#  '327. Kelana, Justin  \n ',
#  '328. Kelly, Michael  \n ',
#  '329. Kelly, Peyton  \n ',
#  "330. Kemp, T'keya  \n ",
#  '331. Kerimbek, Arman  \n ',
#  '332. Kerr, Hannah  \n ',
#  '333. Ketcham, Dylan  \n ',
#  '334. Kha, Jeffrey  \n ',
#  '335. Khamis, Ahmad  \n ',
#  '336. Khan, Abdul Hadi  \n ',
#  '337. Khan, Azeem Raza  \n ',
#  '338. Kim Hoang Trieu, Duong  \n ',
#  '339. Kim, Andrew  \n ',
#  '340. Kim, Dasom  \n ',
#  '341. Kim, Hanseul  \n ',
#  '342. Kim, Hansoo  \n ',
#  '343. Kim, Ji \n  ',
#  '344. Kim, Jung Su  \n ',
#  '345. Kim, Minah  \n ',
#  '346. Kim, Taeeun  \n ',
#  '347. King, James  \n ',
#  '348. Kinsman, Sean  \n ',
#  '349. Kirch, Johan  \n ',
#  '350. Klompmaker, Leah  \n ',
#  '351. Kluender, Mollie  \n ',
#  '352. Kokis, Constantine  \n ',
#  '353. Komatsu, Osamu  \n ',
#  '354. Komori, Corianne  \n ',
#  '355. Kong, Dexiu  \n ',
#  '356. Koppa, Dustin  \n ',
#  '357. Kramer, Charles  \n ',
#  '358. Krausz, Ephraim  \n ',
#  '359. Kruithof, Stephanie  \n ',
#  '360. Kwan, Wesley  \n ',
#  '361. Kwok, Michael  \n ',
#  '362. LaBott, Evan  \n ',
#  '363. Lai, Ho Yeung  \n ',
#  '364. Lai, Jou\n-Hua  \n ',
#  '365. Lamoreaux, Colin  \n ',
#  '366. Lampo, Allison  \n ',
#  '367. Lan, Tian  \n ',
#  '368. Lan, Yifan  \n ',
#  '369. Lane, Corinne  \n ',
#  '370. Lane, Jared  \n ',
#  '371. Lapointe, Benjamin  \n ',
#  '372. Lau, Yiu Lung Peter  \n ',
#  '373. Lay, Dillon Kai Jing  \n ',
#  '374. Le, Brandon  \n ',
#  '375. Leano, Nicole  \n ',
#  '376. LeClair, Jennifer  \n ',
#  '377. Lee, Albert  \n ',
#  '378. Lee, Daniel Jacob \n ',
#  '379. Lee, Dong June  \n ',
#  '380. Lee, Helen  \n ',
#  '381. Lee, Ho Yin  \n ',
#  '382. Lee, I\n-Han  \n ',
#  '383. Lee, Jung Hea  \n ',
#  '384. Lee, Jungpyung  \n ',
#  '385. Lee, Na Young  \n ',
#  '386. Lee, Sae Hee  \n ',
#  '387. Lee, Songhee  \n ',
#  '388. Lee, Sungmin  \n ',
#  '389. Lee, Thomas  \n ',
#  '390. Lee, Yin Tao Candice  \n ',
#  '391. Lee, Yongeun  \n ',
#  '392. Lentz, Jacob  \n ',
#  '393. Lester, Jason  \n ',
#  '394. Levine, Scott  \n ',
#  '395. Li, Hanyi  \n ',
#  '396. Li, Jiahui  \n ',
#  '397. Li, Jianglin  \n ',
#  '398. Li, Jiazhi  \n ',
#  '399. Li, Jinglin  \n ',
#  '400. Li, Nan  \n ',
#  '401. Li, Ning  \n ',
#  '402. Li, Peilin  \n ',
#  '403. Li, Ruijie  \n ',
#  '404. Li, Ruocheng  \n ',
#  '405. Li, Shiyao  \n ',
#  '406. Li, Xiaolin  \n ',
#  '407. Li, Xinrong  \n ',
#  '408. Li, Xueyin  \n ',
#  '409. Li, Yan  \n ',
#  '410. Li, Yuang  \n ',
#  '411. Li, Yufeng  \n ',
#  '412. Li, Zaomiao  \n ',
#  '413. Li, Zhiyu  \n ',
#  '414. Li, Ziyue  \n ',
#  '415. Liang, Yang  \n ',
#  '416. Liang, Yanxuan  \n ',
#  '417. Liao, Yumeng  \n ',
#  '418. Liddell, Alan  \n ',
#  '419. Liew, Shu Yong  \n ',
#  '420. Lim, Hui Xing  \n ',
#  '421. Lim, Sunwoo  \n ',
#  '422. Lim, Yih Tong \n ',
#  '423. Lin, Fubai  \n ',
#  '424. Lin, Hanyu  \n ',
#  '425. Lin, Junfeng  \n ',
#  '426. Lin, \nQinyi  \n ',
#  '427. Lin, Siteng  \n ',
#  '428. Lin, Yen Yu  \n ',
#  '429. Liu, Aixue  \n ',
#  '430. Liu, Fang  \n ',
#  '431. Liu, Hong  \n ',
#  '432. Liu, Jingchi  \n ',
#  '433. Liu, Lulu  \n ',
#  '434. Liu, Muzi  \n ',
#  '435. Liu, Nanhung  \n ',
#  '436. Liu, Peiqiao  \n ',
#  '437. Liu, Qiao  \n ',
#  '438. Liu, Xin  \n ',
#  '439. Liu, Yada  \n ',
#  '440. Liu, Yanwen  \n ',
#  '441. Liu, Yu  \n ',
#  '442. Liu, Zhangyan  \n ',
#  '443. Liu, Zheng  \n ',
#  '444. Liu, Zhonghao  \n ',
#  '445. Lo, David  \n ',
#  '446. Lo, Peter  \n ',
#  '447. Lobe Lobas, Louis\n-Stephane  \n ',
#  '448. Loftus, Thomas  \n ',
#  '449. Lok, Chiyuen  \n ',
#  '450. Loo, Long Tin  \n ',
#  '451. Lootens, Justin  \n ',
#  '452. Loper, Jacob  \n ',
#  '453. Lord, Austin  \n ',
#  '454. Lovera\n-Ives, Brandon  \n ',
#  '455. Lowry, Joseph  \n ',
#  '456. Lu, Jiaxuan  \n ',
#  '457. Lu, Yiming  \n ',
#  '458. Lu, Yun  \n ',
#  '459. Ludvigsen, Levi  \n ',
#  '460. Luisi, Neal  \n ',
#  '461. Lundy, Ian  \n ',
#  '462. Luo, Xin  \n ',
#  '463. Lupoli, Nicholas  \n ',
#  '464. Lye, Kar Chun  \n ',
#  '465. Lynch, Blake  \n ',
#  '466. Lynch, John  \n ',
#  '467. Lyu, Fan  \n ',
#  '468. Lyu, Jianyi  \n ',
#  '469. Lyu, Shanzheng  \n ',
#  '470. Lyu, Zhou  \n ',
#  '471. Ma, Yupei  \n ',
#  '472. Ma, Zhengxin  \n ',
#  '473. MacCormick, Lindsay  \n ',
#  '474. Maconochie, David  \n ',
#  '475. Mahjoob, Huda  \n ',
#  '476. Mahler, Kiersten  \n ',
#  '477. Mai, Tuming  \n ',
#  '478. Maiola, Colby  \n ',
#  '479. Makowiak, Moses  \n ',
#  '480. Maldonado, Christian  \n ',
#  '481. Malloo, Rithishen  \n ',
#  '482. Mammadrzayev, Elmar  \n ',
#  '483. Manciu, Marian  \n ',
#  '484. Mangrum, Devean  \n ',
#  '485. Mann, Tanner  \n ',
#  '486. Mao, Fanyin  \n ',
#  '487. Marcucci, Dante  \n ',
#  '488. Markin, John Kingsley Essel  \n ',
#  '489. Martin, Chester Alan  \n ',
#  '490. Mauch, L\nakin  \n ',
#  '491. Mauer, David  \n ',
#  '492. Mauro, Michael  \n ',
#  '493. McCaffrey, Emma  \n ',
#  '494. McGahan, Trey  \n ',
#  '495. McKay, Elizabeth  \n ',
#  '496. McKenzie, Kelly  \n ',
#  '497. Mei, Yuxin  \n ',
#  '498. Meimand, Vahid  \n ',
#  '499. Meissner, Theodore  \n ',
#  '500. Meng, Melanie  \n ',
#  '501. Millasovich, Nicolas  \n ',
#  '502. Miller, Caleb  \n ',
#  '503. Miller, Matthew  \n ',
#  '504. Minx, Chris  \n ',
#  '505. Mo, Luokexin  \n ',
#  '506. Mo, Zhonghua  \n ',
#  '507. Mohan, Taarini  \n ',
#  '508. Moore, Brennan  \n ',
#  '509. Mora Salinas, Guillermo  \n ',
#  '510. Moreau, Loic  \n ',
#  '511. Motorykina, Yelena  \n ',
#  '512. Motto, Eva  \n ',
#  '513. Moyer, Ethan  \n ',
#  '514. Mullan, David  \n ',
#  '515. Murray, Ryan  \n ',
#  '516. Nam, Kwang Hyun  \n ',
#  '517. Nash, Jared  \n ',
#  '518. Negron, Ignacio  \n ',
#  '519. Nelson, Anthony  \n ',
#  '520. Ner\ny, Sheryll  \n ',
#  '521. Ng, Chak Yee  \n ',
#  '522. Ngo, Jun Wei  \n ',
#  '523. Nguyen, Anh  \n ',
#  '524. Nguyen, Khanh Huynh Bao \n ',
#  '525. Nguyen, Thuythuong  \n ',
#  '526. Nguyen, Tulinh  \n ',
#  '527. Nie, Shibo  \n ',
#  '528. Nielsen, Avery  \n ',
#  '529. Novak, Jenna  \n ',
#  '530. Novak, Morgan  \n ',
#  "531. O'Connor, Shannon  \n ",
#  '532. Odbaatar, Angirmaa  \n ',
#  '533. Odea, Stephen  \n ',
#  '534. Oh, Semin  \n ',
#  '535. Olenick, Kristina  \n ',
#  '536. Ong, Jan Kendrick  \n ',
#  '537. Ong, Sian Lim  \n ',
#  '538. Ooi, Yi Lin  \n ',
#  "539. O'Reilly, Micheal  \n ",
#  '540. Ostrower, Benjamin  \n ',
#  '541. Ouellette, Justin  \n ',
#  '542. Palacio, Juan  \n ',
#  '543. Palmerton, Bradley  \n ',
#  '544. Pandey, Diwash  \n ',
#  '545. Papneja, Ashwin  \n ',
#  '546. Park, Chanseo  \n ',
#  '547. Park, Sinyoung  \n ',
#  '548. Park, So Yeon  \n ',
#  '549. Park\ner, Robert  \n ',
#  '550. Partelow, Nathaniel  \n ',
#  '551. Patel, Sumil  \n ',
#  '552. Patronik, Grant  \n ',
#  '553. Pedroso, Ricardo Cunha \n ',
#  '554. Peeters, Rob  \n ',
#  '555. Pei, Jianing  \n ',
#  '556. Pellerito, Pietro  \n ',
#  '557. Peng, Hanyang  \n ',
#  '558. Peng, Xiaoru  \n ',
#  '559. Pennewell, Travis  \n ',
#  '560. Pennycook, Denisse  \n ',
#  '561. Perry, Seth  \n ',
#  '562. Petelis, Renee  \n ',
#  '563. Phillips, Jacob  \n ',
#  '564. Pittfield, Connor  \n ',
#  '565. Plante, Morgann  \n ',
#  '566. Pleshty, Benjamin  \n ',
#  '567. Portante, Ubaldo  \n ',
#  '568. Poupart, Antoine  \n ',
#  '569. Prabhu, Shankar  \n ',
#  '570. Prasetya, Yoga Dimas \n ',
#  '571. Preap, Sreynich  \n ',
#  '572. Prell, Jacob  \n ',
#  '573. Priddy, Emily  \n ',
#  '574. Prins, Clay  \n ',
#  '575. Puri, Sijan  \n ',
#  '576. Qi, Zhaoning  \n ',
#  '577. Qian, Haoy\nu  \n ',
#  '578. Qin, Yue  \n ',
#  '579. Qiu, Jian  \n ',
#  '580. Qu, Qihan  \n ',
#  '581. Qu, Siping  \n ',
#  '582. Qu, Zehong  \n ',
#  '583. Qyteza, Daniela  \n ',
#  '584. Rainville, Sean  \n ',
#  '585. Ramirez, Arturo  \n ',
#  '586. Ramsey, Michael  \n ',
#  '587. Raneri, Carolyn  \n ',
#  '588. Rangkas, Christ  \n ',
#  '589. Ranpura, Shril  \n ',
#  '590. Ravelo, Mariano  \n ',
#  '591. Ravuri, Sairam  \n ',
#  '592. Ren, Meifang  \n ',
#  '593. Ren, Owen  \n ',
#  '594. Ren, Xiaoping  Jr.,\n ',
#  '595. Ren, Zefan  \n ',
#  '596. Ren, Zeyu  \n ',
#  '597. Renck, Monica  \n ',
#  '598. Reyes, Alexandria  \n ',
#  '599. Rich, Gabrielle  \n ',
#  '600. Richard, Maxime  \n ',
#  '601. Rios, Angel  \n ',
#  '602. Rizvi, Syed Ali Raza  \n ',
#  '603. Ro, Sydney  \n ',
#  '604. Rocco, Thomas  \n ',
#  '605. Rose, Jacob  \n ',
#  '606. Roys, Neal  \n ',
#  '607. Rummel, Nathan  \n ',
#  '608. Rungruengwattanachai, Matat  \n ',
#  '609. Ryu, Catherine  \n ',
#  '610. Rzewski, Luca  \n ',
#  '611. Sakurai Ishizu, Eduardo Masaki  \n ',
#  '612. Same, Herve  \n ',
#  '613. Samuel, Sajini  \n ',
#  '614. Samuels, Jonathan  \n ',
#  '615. Sanders, Evan  \n ',
#  '616. Santosa, Thomas Jefferson Prasetya \n ',
#  '617. Sari, Maifiana  \n ',
#  '618. Satarova, Maya  \n ',
#  '619. Saucedo, Stephen  \n ',
#  '620. Savakis, Nicholas  \n ',
#  '621. Scanlon, Nicole  \n ',
#  '622. Scannell, Ryan  \n ',
#  '623. Scarpill, Matthew  \n ',
#  '624. Schafer, Abigail  \n ',
#  '625. Schenk, Sandra  \n ',
#  '626. Schlenker, Samuel  \n ',
#  '627. Schloss, Michael  \n ',
#  '628. Schnurbusch, Landon  \n ',
#  '629. Scorza, John  \n ',
#  '630. Scott, Ryan  \n ',
#  '631. Serketich, Logan  \n ',
#  '632. Sernaque Torres, Cesar Augusto  \n ',
#  '633. Serpe, Julianna  \n ',
#  '634. Shah,\n Vedant  \n ',
#  '635. Shahrudin, Amir  \n ',
#  '636. Shefchik, Daniel  \n ',
#  "637. Shen, De'Hong  \n ",
#  '638. Shen, Linfeng  \n ',
#  '639. Shen, Qiannan  \n ',
#  '640. Shen, Weijie  \n ',
#  '641. Shen, Yuqin  \n ',
#  '642. Shen, Zixuan  \n ',
#  '643. Shi, Minmin  \n ',
#  '644. Shields, Marcus  \n ',
#  '645. Shim, Hyungtae  \n ',
#  '646. Shim, Kyu Min  \n ',
#  '647. Shouji, Yu  \n ',
#  '648. Shrivastava, Neelesh  \n ',
#  '649. Shutt, Andrew  \n ',
#  '650. Si, Yuning  \n ',
#  '651. Sills, Marquis  \n ',
#  '652. Sim, Su Yong  \n ',
#  '653. Sin Ting, Toh  \n ',
#  '654. Siton, Ara Marie  \n ',
#  '655. Sitthisirivorakul, Jirat  \n ',
#  '656. Skinner, Garrett  \n ',
#  '657. Smith, Andrew  \n ',
#  '658. Smith, Brookelynn  \n ',
#  '659. Smith, Lauren  \n ',
#  '660. Snyder, Bennett  \n ',
#  '661. Socadagui Casas, Elkin Armando  \n ',
#  '662. Sofian, Felicia  \n ',
#  '663. Sohl, Dan\n   ',
#  '664. Sorensen, Brandon  \n ',
#  '665. Souza, Michelle  \n ',
#  '666. Sperry, Kenley  \n ',
#  '667. Sridharan, Ananya  \n ',
#  '668. Staines, Christopher  \n ',
#  '669. Stapp, Emma  \n ',
#  '670. Stehley, Adam  \n ',
#  '671. Steiner, Kevin  \n ',
#  '672. Stimler, Charles  \n ',
#  '673. Stirrat, Matthew  \n ',
#  '674. St-Laurent, Samuel  \n ',
#  '675. Stretch, Sinclaire  \n ',
#  '676. Strickland, Joseph Whitfield \n ',
#  '677. Su, Zhanyi  \n ',
#  '678. Sugimatsu, Takenori  \n ',
#  '679. Sun, Rachel  \n ',
#  '680. Sun, Tiancheng  \n ',
#  '681. Sun, Yan  \n ',
#  '682. Suroso, Alicia Sophie  \n ',
#  '683. Suryanto, Kevin  \n ',
#  '684. Susu, Zheng  \n ',
#  '685. Sweeney, Megan  \n ',
#  '686. Sylvain, Roxanne  \n ',
#  '687. Szegda, Helen  \n ',
#  '688. Szpylka, Evangeline  \n ',
#  '689. Tal, Noam  \n ',
#  '690. Talbot,\n Noah  \n ',
#  '691. Taleb, Bouchra  \n ',
#  '692. Tam, Ho Yin  \n ',
#  '693. Tan, Highryll  \n ',
#  '694. Tan, Joana Che Ern  \n ',
#  '695. Tang, Chi  \n ',
#  '696. Tang, Linxiao  \n ',
#  '697. Tanji, Mizuki  \n ',
#  '698. Tao, Ran  \n ',
#  '699. Tating, Nicholas  \n ',
#  '700. Tausz, Alexander  \n ',
#  '701. Taylor, Andrew  \n ',
#  '702. Taylor, Jason  \n ',
#  '703. Teh, Ryan Chong Meng  \n ',
#  '704. Teng, Shuyi  \n ',
#  '705. Tenny, Kyle Patrick \n ',
#  '706. Thien Chek Hui, Bryan  \n ',
#  '707. Thomas, Latoya  \n ',
#  '708. Thornton, Annie  \n ',
#  '709. Tiekeu, Sirr Landry \n ',
#  '710. Tobwan, Sahatep  \n ',
#  '711. Tokarsky, Alexander  \n ',
#  '712. Tolar, David  \n ',
#  '713. Tolson, Anne  \n ',
#  '714. Tong, Xinying  \n ',
#  '715. Tran, Nhu  \n ',
#  '716. Trehy, Kevin  \n ',
#  '717. Tremblay, Gabriel  \n ',
#  '718. Trifillis, Maxwell  \n ',
#  '719. Tripathi, Vinay  \n ',
#  '720. Truelock, Jack  \n ',
#  '721. Truong, Florianne  \n ',
#  '722. Truong, Kha Hong \n ',
#  '723. Tsai, Zheng\n-Xin  \n ',
#  '724. Tsogtsaikhan, Anudari  \n ',
#  '725. Tu, Chang  \n ',
#  '726. Tupper, Kyle  \n ',
#  '727. Tweedy, Kelsey  \n ',
#  '728. Unice, Connor  \n ',
#  '729. Valencia Bedoya, Andres  \n ',
#  '730. Valencia, William  \n ',
#  '731. Valladares, Felipe  \n ',
#  '732. Vo Thanh, Phuong  \n ',
#  '733. Vullo, Trevor  \n ',
#  '734. Walker, Alex  \n ',
#  '735. Walsh, Ryan  \n ',
#  '736. Wan, Lawrence  \n ',
#  '737. Wang, Han  \n ',
#  '738. Wang, Hao\n-Yuan  \n ',
#  '739. Wang, Junying  \n ',
#  '740. Wang, Kejun  \n ',
#  '741. Wang, Puxuan  \n ',
#  '742. Wang, Siyu  \n ',
#  '743. Wang, Wenjing  \n ',
#  '744. Wang, Xiaolin  \n ',
#  '745. Wang, Xiaoya  \n ',
#  '746. Wang, Xixi  \n ',
#  '747. Wang, Yahao  \n ',
#  '748. Wang, Yeke  \n ',
#  '749. Wang, Yingkai  \n ',
#  '750. Wang, Yisu  \n ',
#  '751. Wang, Yixin  \n ',
#  '752. Wang, Yumeng  \n ',
#  '753. Wang, Zeqi  \n ',
#  '754. Watson, Brendan  \n ',
#  '755. Weber, Daniel  \n ',
#  '756. Wei, Wei  \n ',
#  '757. Wei, Yu  \n ',
#  '758. Weigel, Aaron  \n ',
#  '759. Wen, Yu  \n ',
#  '760. Wendeln, Josh  \n ',
#  '761. Wetzler, Harrison  \n ',
#  '762. Whelpley, Jon  \n ',
#  '763. Wilde, Nathaniel  \n ',
#  '764. Williams, Elijah  \n ',
#  '765. Williams, Triston  \n ',
#  '766. Wilson, Christopher Lawrence \n ',
#  '767. Wilson, Tosha  \n ',
#  '768. Winters, Amber  \n ',
#  '769. Wisor, Zane  \n ',
#  '770. Wong, Chun Keat  \n ',
#  '771. Wong, Kee Hang  \n ',
#  '772. Woodring, Alexandra  \n ',
#  '773. Wu, Eric  \n ',
#  '774. Wu, Jinlin  \n ',
#  '775. Wu, Junji  \n ',
#  '776. Wu, Leilei  \n ',
#  '777. Wu, Susan  \n ',
#  '778. Wu, Xiaowei  \n ',
#  '779. Wu, Xue Ling  \n ',
#  '780. Wu, Yue  \n ',
#  '781. Xian, Chulin  \n ',
#  '782. Xiao, Yufeng  \n ',
#  '783. Xinyan, Ge  \n ',
#  '784. Xiong, Xinwei  \n ',
#  '785. Xu, Chang  \n ',
#  '786. Xu, Fan  \n ',
#  '787. Xu, Jia  \n ',
#  '788. Xu, Jiamin  \n ',
#  '789. Xu, Jianan  \n ',
#  '790. Xu, Mengyuan  \n ',
#  '791. Xu, Ranyi  \n ',
#  '792. Xu, Shengyao  \n ',
#  '793. Xu, Shizhou  \n ',
#  '794. Xu, Su  \n ',
#  '795. Xu, Xinyu  \n ',
#  '796. Xu, Yi  \n ',
#  '797. Yan, Kang  \n ',
#  '798. Yang, Han  \n ',
#  '799. Yang, Mingya  \n ',
#  '800. Yang, Yajie  \n ',
#  '801. Yao, Lanqiu  \n ',
#  '802. Yao, Shuoyi  \n ',
#  '803. Yap, Lawrence Vincent  \n ',
#  '804. Ye, Chaoqi  \n ',
#  '805. Ye, Qiang  \n ',
#  '806. Ye, Zhongsheng  \n ',
#  '807. Yeazel, Linnea  \n ',
#  '808. Yiantsos, Andonis  \n ',
#  '809. Yin, Menghua  \n ',
#  '810. Yoo, Woongchae  \n ',
#  '811. Yoon, Hyeongho  \n ',
#  '812. Yoon, Sung Min  \n ',
#  '813. Yoong, Nicholas Wen Gen  \n ',
#  '814. You, Ran  \n ',
#  '815. Youn, Joshua  \n ',
#  '816. Young Hoon, Mok  \n ',
#  '817. Young, Nicholas Ty \n ',
#  '818. Yu, Hao\n-Nien  \n ',
#  '819. Yu, Lu  \n ',
#  '820. Yu, Shu San  \n ',
#  '821. Yu, Xinghua  \n ',
#  '822. Yu, Xinyi  \n ',
#  '823. Yu, Yian  \n ',
#  '824. Yu, Zihan  \n ',
#  '825. Yuan, Shuhao  \n ',
#  '826. Yuan, Yu  \n ',
#  '827. Yue, Sai  \n ',
#  '828. Yuen Nee, Ng  \n ',
#  '829. Yuen, Po Yi  \n ',
#  '830. Zaborowski, Zachary  \n ',
#  '831. Zeidan, Natalie  \n ',
#  '832. Zendejas Limon, Cesar  \n ',
#  '833. Zhai, Yixian  \n ',
#  '834. Zhang, Dandan  \n ',
#  '835. Zhang, Hanchun  \n ',
#  '836. Zhang, Haotian  \n ',
#  '837. Zhang, Hui  \n ',
#  '838. Zhang, Jie  \n ',
#  '839. Zhang, Jin  \n ',
#  '840. Zhang, Jingyang  \n ',
#  '841. Zhang, Julie  \n ',
#  '842. Zhang, Lei  \n ',
#  '843. Zhang, Mingwei  \n ',
#  '844. Zhang, Oscar Yong Qi  \n ',
#  '845. Zhang, Peiyi  \n ',
#  '846. Zhang, Runze  \n ',
#  '847. Zhang, Shengning  \n ',
#  '848. Zhang, Terry  \n ',
#  '849. Zhang, Weilong  \n ',
#  '850. Zhang, Xiaofan  \n ',
#  '851. Zhang, Xin  \n ',
#  '852. Zhang, Xuefei  \n ',
#  '853. Zhang, Yilin  \n ',
#  '854. Zhang, Yuqi  \n ',
#  '855. Zhang, Ziling  \n ',
#  '856. Zhao, Dannan  \n ',
#  '857. Zhao, Min  \n ',
#  '858. Zhao, Qian  \n ',
#  '859. Zhao, Ran  \n ',
#  '860. Zhao, Siyu  \n ',
#  '861. Zhao, Songqing  \n ',
#  '862. Zhao, Tianhao  \n ',
#  '863. Zhao, Wei  \n ',
#  '864. Zhao, Yuhan  \n ',
#  '865. Zhen, Yongqi  \n ',
#  '866. Zheng, Ch\nufan  \n ',
#  '867. Zheng, Tianxiang  \n ',
#  '868. Zhong, Haolun  \n ',
#  '869. Zhou, Jin Hua  \n ',
#  '870. Zhou, Meihan  \n ',
#  '871. Zhou, Michael  \n ',
#  '872. Zhou, Rouhan  \n ',
#  '873. Zhou, Xiangting  \n ',
#  '874. Zhou, Yifan  \n ',
#  '875. Zhu, Beili  \n ',
#  '876. Zhu, Daping  \n ',
#  '877. Zhu, Huilin  \n ',
#  '878. Zhu, Ning  \n ',
#  '879. Zhu, Ricky  \n ',
#  '880. Zhunyang, Xu  \n ',
#  '881. Ziegelman, Dean  \n ',
#  '882. Zikpi, Christian  \n ',
#  '883. Zu, Ling  \n ']

# %% [markdown]
# We want to extract the first and last names of each exam taker. We remove the numbers at the start of each line and the extra text at the end of each line and split each string into a list of two strings for first and last name.

# %%
def formatName(nameString):
    nameString = re.sub(r'^[0-9]+\.\s','',nameString) #Remove Leading Numbers
    nameString = re.sub('\n','',nameString) #Remove newline
    nameString = nameString.rstrip() #Remove trailing whitespace
    namePair = nameString.split(", ", 1) #Split strings
    return namePair

[formatName(name) for name in rawNames]
# Out:
# [['Abbas', 'Fizza'],
#  ['Abdul Aziz', 'Talha'],
#  ['Ackerman', 'Samuel'],
#  ['Acosta', 'Ana'],
#  ['Acri', 'Sierra'],
#  ['Adamic', 'Haley Michelle'],
#  ['Adamo', 'Anthony'],
#  ['Adeagbo', 'Oluwakemi'],
#  ['Adlan', 'Anis Syafiqah'],
#  ['Agrawal', 'Yogesh'],
#  ['Aguayo Dupin', 'Nicolas Antonio'],
#  ['Aguirre', 'Andrew'],
#  ['Alam', 'Farheen Kabir'],
#  ['Alaskar', 'Ruba'],
#  ['Albano', 'Carl'],
#  ['Alberto', 'Janette'],
#  ['Al-Burti', 'Aliaa'],
#  ['Aldaoud', 'Abir'],
#  ['Alfallaj', 'Abdulkarim'],
#  ['Ali', 'Nade'],
#  ['Allen', 'Asrielle'],
#  ['Alqahtani', 'Reem Saleh'],
#  ['Alsayel', 'Abdulrhman'],
#  ['Alvarado', 'John Renz'],
#  ['Amstislavskiy', 'Eric'],
#  ['Anderson', 'Lance'],
#  ['Anderson', 'Michael'],
#  ['Armanious', 'Miriam'],
#  ['Asavatheputhai', 'Pongsathorn'],
#  ['Aselisewine', 'Wisdom'],
#  ['Astiazaran', 'Juan'],
#  ['Attara', 'Florence'],
#  ['Aun', 'Syed'],
#  ['Avila', 'Monica'],
#  ['Awotwe', 'Emmanuel'],
#  ['Ayers', 'Megan'],
#  ['Bahr', 'Anna'],
#  ['Bahr', 'Spencer'],
#  ['Baillie', 'Madeline'],
#  ['Bajsicka', 'Weronika'],
#  ['Bakri', 'Nada'],
#  ['Baraka', 'Mira'],
#  ['Barash', 'Jacqueline'],
#  ['Barman', 'Tyler'],
#  ['Barrett', 'Brooke'],
#  ['Bartlett', 'Connor'],
#  ['Basquez', 'Nichol'],
#  ['Bautista', 'Ivan Christian'],
#  ['Bechhofer', 'Samson'],
#  ['Behrend', 'Whitney'],
#  ['Bellefeuille', 'Vincent'],
#  ['Bender', 'Luke'],
#  ['Bennett', 'Bryan'],
#  ['Berger', 'Rivka'],
#  ['Best', 'Abigail'],
#  ['Bhula', 'Pooja'],
#  ['Bidlingmaier', 'Robert'],
#  ['Birkicht', 'Taleah'],
#  ['Blair', 'Derek'],
#  ['Blair', 'Maria'],
#  ['Blake', 'David'],
#  ['Blomster', 'Daniel'],
#  ['Blyuss', 'Nicole'],
#  ['Boamah', 'Emmanuel'],
#  ['Bogdanis', 'David'],
#  ['Bonneville', 'Daniel'],
#  ['Boontem', 'Arissara'],
#  ['Brackey', 'Adrienne'],
#  ['Brand', 'Franklin-Xavier'],
#  ['Braun', 'Brittnee'],
#  ['Brauns', 'Kaleigh'],
#  ['Brumley', 'Austin'],
#  ['Buchanan-Boothe', 'Shawntoll'],
#  ['Burlingame', 'James'],
#  ['Burns', 'Jackson'],
#  ['Butsaraphuphuengpham', 'Sitiphon'],
#  ['Cahill', 'Joseph A.'],
#  ['Cai', 'Wenting'],
#  ['Cain', 'Levi'],
#  ['Cairney', 'Zachary'],
#  ['Cairo', 'Kevin'],
#  ['Cao', 'Mengya'],
#  ['Cao', 'Siqing'],
#  ['Cappaert', 'Mark'],
#  ['Carlstrom', 'Joseph'],
#  ['Chahalis', 'Taylor'],
#  ['Chan', 'Jack'],
#  ['Chan', 'Kyle'],
#  ['Chang', 'Yu-Feng'],
#  ['Chao', 'Guo An'],
#  ['Chavez Quinonez', 'Daniel Rafael'],
#  ['Chen', 'Chris'],
#  ['Chen', 'Hanqi'],
#  ['Chen', 'I-Chun'],
#  ['Chen', 'Jian-He'],
#  ['Chen', 'Jinyan'],
#  ['Chen', 'Kaini'],
#  ['Chen', 'Lei'],
#  ['Chen', 'Mengfan'],
#  ['Chen', 'Po Jui'],
#  ['Chen', 'Qian'],
#  ['Chen', 'Siyuan'],
#  ['Chen', 'Wan-Hsuan'],
#  ['Chen', 'Wilton'],
#  ['Chen', 'Xiaodi'],
#  ['Chen', 'Xudong'],
#  ['Chen', 'Yanzhu'],
#  ['Chen', 'Yitong'],
#  ['Cheng', 'Lam'],
#  ['Cho', 'Sangwook'],
#  ['Choi', 'Jungyoon'],
#  ['Chong', 'Kar Ken'],
#  ['Chu', 'Calvin'],
#  ['Chueaphet', 'Sasitorn'],
#  ['Colabatistto', 'Kristen'],
#  ['Colegrove', 'Dale'],
#  ['Collado', 'Christian Kenneth'],
#  ['Cooper', 'Bryan'],
#  ['Corbeil', 'Alexandre'],
#  ['Cornett', 'Julie'],
#  ['Coutinho', 'Seth'],
#  ['Coyne', 'John'],
#  ['Craig', 'Andrew'],
#  ['Crow', 'Connor'],
#  ['Cruse', 'Robert  II,'],
#  ['Curtis', 'Devon'],
#  ['Cushing', 'Jacob'],
#  ['Daniele-Dinndorf', 'Anna Louise'],
#  ['Daniels', 'Walter'],
#  ['Danzer', 'Craig'],
#  ['Dao Thi Ha', 'Phuong'],
#  ['Davies', 'Steven'],
#  ['de Castro Perez', 'Ines'],
#  ['Deaver', 'Karen'],
#  ['DeBenedictis', 'Nikolette'],
#  ['DeBlieux', 'Jefferson  V,'],
#  ['Deen', 'Stanley'],
#  ['DelGrande', 'Sarah'],
#  ['Deng', 'Haohua'],
#  ['Desai', 'Hely'],
#  ['Dick', 'Jake'],
#  ['DiDio', 'Kayla-Mae'],
#  ['Dimitrov', 'Martin'],
#  ['Ding', 'Yijing'],
#  ['Ding', 'Ying'],
#  ['Dockter', 'Brianna'],
#  ['Dokmanovich', 'Emma'],
#  ['Dominique', 'Yan'],
#  ['Dona', 'Michele'],
#  ['Donald', 'Stephen'],
#  ['Dong', 'Guoxiu'],
#  ['Dong', 'Jiayu'],
#  ['Dong', 'Wenli'],
#  ['Dooley', 'Meredith'],
#  ['Dougherty', 'Steven'],
#  ['Dowling', 'Matthew Patrick'],
#  ['Doyle', 'Andrew'],
#  ['Dozer', 'Grant'],
#  ['Drewes', 'Will'],
#  ['Du', 'Noah'],
#  ['Du', 'Qingyang'],
#  ['Duan', 'Bingjie'],
#  ['Dulashko', 'Tatiana'],
#  ['Eckardt', 'Benjamin'],
#  ['Edwards', 'Brandon'],
#  ['Emerick', 'Brooke'],
#  ['Eoff', 'Jared'],
#  ['Eriksson', 'Jake'],
#  ['Ernster', 'John'],
#  ['Erquiaga', 'Sebastian'],
#  ['Esparza', 'Miranda'],
#  ['Fan', 'Jiayue'],
#  ['Fan', 'Shiyu'],
#  ['Fan', 'Yao'],
#  ['Fan', 'Yuqian'],
#  ['Fang', 'Yuping'],
#  ['Fang', 'Zheng'],
#  ['Fantevi', 'Andrews'],
#  ['Farhadova', 'Aisha'],
#  ['Farooqi', 'Bisma Narmeen'],
#  ['Fehrman', 'Karli'],
#  ['Fenghua', 'Liu'],
#  ['Fernandez', 'Christie Anne'],
#  ['Fettich', 'William'],
#  ['Fisher', 'Thomas'],
#  ['Fitzpatrick', 'Brendan'],
#  ['Flores', 'Homero'],
#  ['Frydryk', 'Paul'],
#  ['Fu', 'Wanglu'],
#  ['Fujita', 'Suguru'],
#  ['Fuller', 'Benjamin'],
#  ['Fung', 'Jonathan'],
#  ['Gai', 'Yanan'],
#  ['Gallis', 'John'],
#  ['Gambale', 'John'],
#  ['Gao', 'Congyi'],
#  ['Gao', 'Fan'],
#  ['Gao', 'Lei'],
#  ['Gao', 'Tianyou'],
#  ['Gao', 'Xiao'],
#  ['Garcia', 'Ernesto'],
#  ['Garcia', 'Tatiana'],
#  ['Gatpolintan', 'Danielle Ann'],
#  ['Geiger', 'Katherine'],
#  ['Geng', 'Guangzhen'],
#  ['Geng', 'Lijie'],
#  ['Gentry', 'Nicholas'],
#  ['Gestetner', 'Joseph'],
#  ['Gillespie', 'Robert'],
#  ['Gillette', 'David'],
#  ['Gipson', 'Danita'],
#  ['Giuffre', 'Anthony'],
#  ['Gleeson-Rosson', 'Brian'],
#  ['Go', 'Inmu'],
#  ['Goel', 'Jaidev'],
#  ['Goff', 'Dustin'],
#  ['Goh', 'Ka Mun'],
#  ['Goh', 'Pei Shan'],
#  ['Goldberg', 'Matisyahu'],
#  ['Gonzalez Orta', 'Rodolfo'],
#  ['Goto', 'Yosuke'],
#  ['Grainey', 'Elizabeth'],
#  ['Grueneberg', 'Jeffrey'],
#  ['Gu', 'Junwen'],
#  ['Guan', 'Peijun'],
#  ['Guan', 'Yanjia (Kyle)'],
#  ['Gundersen', 'John'],
#  ['Guo', 'Bingcui'],
#  ['Guo', 'Caiyun'],
#  ['Guo', 'Chenxi'],
#  ['Guo', 'Keli'],
#  ['Ha', 'Ngoc-Kim'],
#  ['Haight', 'Russ'],
#  ['Hallenbeck', 'Elise'],
#  ['Hanks-Witaszek', 'Elise'],
#  ['Hansen', 'Johanna'],
#  ['Hanyin', 'Mao'],
#  ['Hao', 'Yi'],
#  ['Hao', 'Yuewei'],
#  ['Harding', 'Chris'],
#  ['Harnden', 'Matthew Tyler'],
#  ['Hasija', 'Anika'],
#  ['Hawkins', 'Jordan'],
#  ['Hawkins', 'William'],
#  ['He', 'Daijie'],
#  ['He', 'Fou'],
#  ['He', 'Yunbo'],
#  ['Heatherman', 'Bo'],
#  ['Heimbrock', 'Simon'],
#  ['Hendricks', 'Mercedes'],
#  ['Hernandez', 'Jesus Octavio Rodriguez'],
#  ['Hillman', 'Sean'],
#  ['Hippisley', 'Joseph'],
#  ['Hirsch', 'Jeremy'],
#  ['Hollman', 'Christopher'],
#  ['Holton', 'James'],
#  ['Honiss', 'Zachary'],
#  ['Hooley', 'David'],
#  ['Hott', 'Harrison'],
#  ['How Yee Chong', 'Jordan Dean'],
#  ['Hsiao', 'Yu-Tyng'],
#  ['Hsin', 'Pei-Ni'],
#  ['Hsu', 'Kui Yuan'],
#  ['Hu', 'Clarence'],
#  ['Hu', 'Hongda'],
#  ['Hu', 'Jingning'],
#  ['Hu', 'Xiaoyu'],
#  ['Hu', 'Xinqi'],
#  ['Hua', 'Vy Ngoc Anh'],
#  ['Huang', 'Haichen'],
#  ['Huang', 'Qianxin'],
#  ['Huang', 'Raymond'],
#  ['Huang', 'Shaowei'],
#  ['Huang', 'Xian Ting'],
#  ['Huang', 'Xinhui'],
#  ['Huang', 'Yu-Hsiang'],
#  ['Huang', 'Yuqi'],
#  ['Huang', 'Yuting'],
#  ['Hue', 'Michael'],
#  ['Huggins', 'Alkin'],
#  ['Huixin', 'Eu'],
#  ['Hung', 'Samantha'],
#  ['Huo', 'Siqing'],
#  ['Hupp', 'Zachary'],
#  ['Hussain', 'Syed Zohaib'],
#  ['Huynh', 'Son'],
#  ['Huysman', 'Liam'],
#  ['Hyland', 'Brittany'],
#  ['Hyun', 'Juhong'],
#  ['Ibiribigbe', 'Saidat'],
#  ['Irshad', 'Umar'],
#  ['Ishida', 'Robyn'],
#  ['Iwanicka', 'Sylwia'],
#  ['Jackman', 'Adriana'],
#  ['Jackman', 'Calen'],
#  ['Jackson', 'Benjamin'],
#  ['Jakkraphobyothin', 'Ponthakorn'],
#  ['James', 'Lincoln'],
#  ['Jang', 'Jinho'],
#  ['Jensen', 'Peter'],
#  ['Jeong', 'Myeonghwan'],
#  ['Jepsen', 'Alison'],
#  ['Jepsen', 'Jeremiah'],
#  ['Jia Jin', 'Chua'],
#  ['Jiang', 'Shuyue'],
#  ['Jiang', 'Tongyao'],
#  ['Jiang', 'Weiyi'],
#  ['Jiang', 'Yuzhaoran'],
#  ['Jin', 'Jiachen'],
#  ['Jing', 'Liqing'],
#  ['Jochem', 'Josef'],
#  ['John', 'Stanley'],
#  ['Johnston', 'Lucas'],
#  ['Jones', 'Erica'],
#  ['Jung', 'Heedo'],
#  ['Kabore', 'Elisee'],
#  ['Kacmarski', 'Michaela'],
#  ['Kah Foong', 'Edmund Hong'],
#  ['Kaixiong', 'Huang'],
#  ['Kalthoff', 'Jenna'],
#  ['Kamaraj', 'Suganthi'],
#  ['Kan', 'Jun Yang'],
#  ['Kane', 'Matthew'],
#  ['Kang', 'Emily'],
#  ['Kary', 'Mack'],
#  ['Kavanaugh', 'Luke'],
#  ['Kelana', 'Justin'],
#  ['Kelly', 'Michael'],
#  ['Kelly', 'Peyton'],
#  ['Kemp', "T'keya"],
#  ['Kerimbek', 'Arman'],
#  ['Kerr', 'Hannah'],
#  ['Ketcham', 'Dylan'],
#  ['Kha', 'Jeffrey'],
#  ['Khamis', 'Ahmad'],
#  ['Khan', 'Abdul Hadi'],
#  ['Khan', 'Azeem Raza'],
#  ['Kim Hoang Trieu', 'Duong'],
#  ['Kim', 'Andrew'],
#  ['Kim', 'Dasom'],
#  ['Kim', 'Hanseul'],
#  ['Kim', 'Hansoo'],
#  ['Kim', 'Ji'],
#  ['Kim', 'Jung Su'],
#  ['Kim', 'Minah'],
#  ['Kim', 'Taeeun'],
#  ['King', 'James'],
#  ['Kinsman', 'Sean'],
#  ['Kirch', 'Johan'],
#  ['Klompmaker', 'Leah'],
#  ['Kluender', 'Mollie'],
#  ['Kokis', 'Constantine'],
#  ['Komatsu', 'Osamu'],
#  ['Komori', 'Corianne'],
#  ['Kong', 'Dexiu'],
#  ['Koppa', 'Dustin'],
#  ['Kramer', 'Charles'],
#  ['Krausz', 'Ephraim'],
#  ['Kruithof', 'Stephanie'],
#  ['Kwan', 'Wesley'],
#  ['Kwok', 'Michael'],
#  ['LaBott', 'Evan'],
#  ['Lai', 'Ho Yeung'],
#  ['Lai', 'Jou-Hua'],
#  ['Lamoreaux', 'Colin'],
#  ['Lampo', 'Allison'],
#  ['Lan', 'Tian'],
#  ['Lan', 'Yifan'],
#  ['Lane', 'Corinne'],
#  ['Lane', 'Jared'],
#  ['Lapointe', 'Benjamin'],
#  ['Lau', 'Yiu Lung Peter'],
#  ['Lay', 'Dillon Kai Jing'],
#  ['Le', 'Brandon'],
#  ['Leano', 'Nicole'],
#  ['LeClair', 'Jennifer'],
#  ['Lee', 'Albert'],
#  ['Lee', 'Daniel Jacob'],
#  ['Lee', 'Dong June'],
#  ['Lee', 'Helen'],
#  ['Lee', 'Ho Yin'],
#  ['Lee', 'I-Han'],
#  ['Lee', 'Jung Hea'],
#  ['Lee', 'Jungpyung'],
#  ['Lee', 'Na Young'],
#  ['Lee', 'Sae Hee'],
#  ['Lee', 'Songhee'],
#  ['Lee', 'Sungmin'],
#  ['Lee', 'Thomas'],
#  ['Lee', 'Yin Tao Candice'],
#  ['Lee', 'Yongeun'],
#  ['Lentz', 'Jacob'],
#  ['Lester', 'Jason'],
#  ['Levine', 'Scott'],
#  ['Li', 'Hanyi'],
#  ['Li', 'Jiahui'],
#  ['Li', 'Jianglin'],
#  ['Li', 'Jiazhi'],
#  ['Li', 'Jinglin'],
#  ['Li', 'Nan'],
#  ['Li', 'Ning'],
#  ['Li', 'Peilin'],
#  ['Li', 'Ruijie'],
#  ['Li', 'Ruocheng'],
#  ['Li', 'Shiyao'],
#  ['Li', 'Xiaolin'],
#  ['Li', 'Xinrong'],
#  ['Li', 'Xueyin'],
#  ['Li', 'Yan'],
#  ['Li', 'Yuang'],
#  ['Li', 'Yufeng'],
#  ['Li', 'Zaomiao'],
#  ['Li', 'Zhiyu'],
#  ['Li', 'Ziyue'],
#  ['Liang', 'Yang'],
#  ['Liang', 'Yanxuan'],
#  ['Liao', 'Yumeng'],
#  ['Liddell', 'Alan'],
#  ['Liew', 'Shu Yong'],
#  ['Lim', 'Hui Xing'],
#  ['Lim', 'Sunwoo'],
#  ['Lim', 'Yih Tong'],
#  ['Lin', 'Fubai'],
#  ['Lin', 'Hanyu'],
#  ['Lin', 'Junfeng'],
#  ['Lin', 'Qinyi'],
#  ['Lin', 'Siteng'],
#  ['Lin', 'Yen Yu'],
#  ['Liu', 'Aixue'],
#  ['Liu', 'Fang'],
#  ['Liu', 'Hong'],
#  ['Liu', 'Jingchi'],
#  ['Liu', 'Lulu'],
#  ['Liu', 'Muzi'],
#  ['Liu', 'Nanhung'],
#  ['Liu', 'Peiqiao'],
#  ['Liu', 'Qiao'],
#  ['Liu', 'Xin'],
#  ['Liu', 'Yada'],
#  ['Liu', 'Yanwen'],
#  ['Liu', 'Yu'],
#  ['Liu', 'Zhangyan'],
#  ['Liu', 'Zheng'],
#  ['Liu', 'Zhonghao'],
#  ['Lo', 'David'],
#  ['Lo', 'Peter'],
#  ['Lobe Lobas', 'Louis-Stephane'],
#  ['Loftus', 'Thomas'],
#  ['Lok', 'Chiyuen'],
#  ['Loo', 'Long Tin'],
#  ['Lootens', 'Justin'],
#  ['Loper', 'Jacob'],
#  ['Lord', 'Austin'],
#  ['Lovera-Ives', 'Brandon'],
#  ['Lowry', 'Joseph'],
#  ['Lu', 'Jiaxuan'],
#  ['Lu', 'Yiming'],
#  ['Lu', 'Yun'],
#  ['Ludvigsen', 'Levi'],
#  ['Luisi', 'Neal'],
#  ['Lundy', 'Ian'],
#  ['Luo', 'Xin'],
#  ['Lupoli', 'Nicholas'],
#  ['Lye', 'Kar Chun'],
#  ['Lynch', 'Blake'],
#  ['Lynch', 'John'],
#  ['Lyu', 'Fan'],
#  ['Lyu', 'Jianyi'],
#  ['Lyu', 'Shanzheng'],
#  ['Lyu', 'Zhou'],
#  ['Ma', 'Yupei'],
#  ['Ma', 'Zhengxin'],
#  ['MacCormick', 'Lindsay'],
#  ['Maconochie', 'David'],
#  ['Mahjoob', 'Huda'],
#  ['Mahler', 'Kiersten'],
#  ['Mai', 'Tuming'],
#  ['Maiola', 'Colby'],
#  ['Makowiak', 'Moses'],
#  ['Maldonado', 'Christian'],
#  ['Malloo', 'Rithishen'],
#  ['Mammadrzayev', 'Elmar'],
#  ['Manciu', 'Marian'],
#  ['Mangrum', 'Devean'],
#  ['Mann', 'Tanner'],
#  ['Mao', 'Fanyin'],
#  ['Marcucci', 'Dante'],
#  ['Markin', 'John Kingsley Essel'],
#  ['Martin', 'Chester Alan'],
#  ['Mauch', 'Lakin'],
#  ['Mauer', 'David'],
#  ['Mauro', 'Michael'],
#  ['McCaffrey', 'Emma'],
#  ['McGahan', 'Trey'],
#  ['McKay', 'Elizabeth'],
#  ['McKenzie', 'Kelly'],
#  ['Mei', 'Yuxin'],
#  ['Meimand', 'Vahid'],
#  ['Meissner', 'Theodore'],
#  ['Meng', 'Melanie'],
#  ['Millasovich', 'Nicolas'],
#  ['Miller', 'Caleb'],
#  ['Miller', 'Matthew'],
#  ['Minx', 'Chris'],
#  ['Mo', 'Luokexin'],
#  ['Mo', 'Zhonghua'],
#  ['Mohan', 'Taarini'],
#  ['Moore', 'Brennan'],
#  ['Mora Salinas', 'Guillermo'],
#  ['Moreau', 'Loic'],
#  ['Motorykina', 'Yelena'],
#  ['Motto', 'Eva'],
#  ['Moyer', 'Ethan'],
#  ['Mullan', 'David'],
#  ['Murray', 'Ryan'],
#  ['Nam', 'Kwang Hyun'],
#  ['Nash', 'Jared'],
#  ['Negron', 'Ignacio'],
#  ['Nelson', 'Anthony'],
#  ['Nery', 'Sheryll'],
#  ['Ng', 'Chak Yee'],
#  ['Ngo', 'Jun Wei'],
#  ['Nguyen', 'Anh'],
#  ['Nguyen', 'Khanh Huynh Bao'],
#  ['Nguyen', 'Thuythuong'],
#  ['Nguyen', 'Tulinh'],
#  ['Nie', 'Shibo'],
#  ['Nielsen', 'Avery'],
#  ['Novak', 'Jenna'],
#  ['Novak', 'Morgan'],
#  ["O'Connor", 'Shannon'],
#  ['Odbaatar', 'Angirmaa'],
#  ['Odea', 'Stephen'],
#  ['Oh', 'Semin'],
#  ['Olenick', 'Kristina'],
#  ['Ong', 'Jan Kendrick'],
#  ['Ong', 'Sian Lim'],
#  ['Ooi', 'Yi Lin'],
#  ["O'Reilly", 'Micheal'],
#  ['Ostrower', 'Benjamin'],
#  ['Ouellette', 'Justin'],
#  ['Palacio', 'Juan'],
#  ['Palmerton', 'Bradley'],
#  ['Pandey', 'Diwash'],
#  ['Papneja', 'Ashwin'],
#  ['Park', 'Chanseo'],
#  ['Park', 'Sinyoung'],
#  ['Park', 'So Yeon'],
#  ['Parker', 'Robert'],
#  ['Partelow', 'Nathaniel'],
#  ['Patel', 'Sumil'],
#  ['Patronik', 'Grant'],
#  ['Pedroso', 'Ricardo Cunha'],
#  ['Peeters', 'Rob'],
#  ['Pei', 'Jianing'],
#  ['Pellerito', 'Pietro'],
#  ['Peng', 'Hanyang'],
#  ['Peng', 'Xiaoru'],
#  ['Pennewell', 'Travis'],
#  ['Pennycook', 'Denisse'],
#  ['Perry', 'Seth'],
#  ['Petelis', 'Renee'],
#  ['Phillips', 'Jacob'],
#  ['Pittfield', 'Connor'],
#  ['Plante', 'Morgann'],
#  ['Pleshty', 'Benjamin'],
#  ['Portante', 'Ubaldo'],
#  ['Poupart', 'Antoine'],
#  ['Prabhu', 'Shankar'],
#  ['Prasetya', 'Yoga Dimas'],
#  ['Preap', 'Sreynich'],
#  ['Prell', 'Jacob'],
#  ['Priddy', 'Emily'],
#  ['Prins', 'Clay'],
#  ['Puri', 'Sijan'],
#  ['Qi', 'Zhaoning'],
#  ['Qian', 'Haoyu'],
#  ['Qin', 'Yue'],
#  ['Qiu', 'Jian'],
#  ['Qu', 'Qihan'],
#  ['Qu', 'Siping'],
#  ['Qu', 'Zehong'],
#  ['Qyteza', 'Daniela'],
#  ['Rainville', 'Sean'],
#  ['Ramirez', 'Arturo'],
#  ['Ramsey', 'Michael'],
#  ['Raneri', 'Carolyn'],
#  ['Rangkas', 'Christ'],
#  ['Ranpura', 'Shril'],
#  ['Ravelo', 'Mariano'],
#  ['Ravuri', 'Sairam'],
#  ['Ren', 'Meifang'],
#  ['Ren', 'Owen'],
#  ['Ren', 'Xiaoping  Jr.,'],
#  ['Ren', 'Zefan'],
#  ['Ren', 'Zeyu'],
#  ['Renck', 'Monica'],
#  ['Reyes', 'Alexandria'],
#  ['Rich', 'Gabrielle'],
#  ['Richard', 'Maxime'],
#  ['Rios', 'Angel'],
#  ['Rizvi', 'Syed Ali Raza'],
#  ['Ro', 'Sydney'],
#  ['Rocco', 'Thomas'],
#  ['Rose', 'Jacob'],
#  ['Roys', 'Neal'],
#  ['Rummel', 'Nathan'],
#  ['Rungruengwattanachai', 'Matat'],
#  ['Ryu', 'Catherine'],
#  ['Rzewski', 'Luca'],
#  ['Sakurai Ishizu', 'Eduardo Masaki'],
#  ['Same', 'Herve'],
#  ['Samuel', 'Sajini'],
#  ['Samuels', 'Jonathan'],
#  ['Sanders', 'Evan'],
#  ['Santosa', 'Thomas Jefferson Prasetya'],
#  ['Sari', 'Maifiana'],
#  ['Satarova', 'Maya'],
#  ['Saucedo', 'Stephen'],
#  ['Savakis', 'Nicholas'],
#  ['Scanlon', 'Nicole'],
#  ['Scannell', 'Ryan'],
#  ['Scarpill', 'Matthew'],
#  ['Schafer', 'Abigail'],
#  ['Schenk', 'Sandra'],
#  ['Schlenker', 'Samuel'],
#  ['Schloss', 'Michael'],
#  ['Schnurbusch', 'Landon'],
#  ['Scorza', 'John'],
#  ['Scott', 'Ryan'],
#  ['Serketich', 'Logan'],
#  ['Sernaque Torres', 'Cesar Augusto'],
#  ['Serpe', 'Julianna'],
#  ['Shah', 'Vedant'],
#  ['Shahrudin', 'Amir'],
#  ['Shefchik', 'Daniel'],
#  ['Shen', "De'Hong"],
#  ['Shen', 'Linfeng'],
#  ['Shen', 'Qiannan'],
#  ['Shen', 'Weijie'],
#  ['Shen', 'Yuqin'],
#  ['Shen', 'Zixuan'],
#  ['Shi', 'Minmin'],
#  ['Shields', 'Marcus'],
#  ['Shim', 'Hyungtae'],
#  ['Shim', 'Kyu Min'],
#  ['Shouji', 'Yu'],
#  ['Shrivastava', 'Neelesh'],
#  ['Shutt', 'Andrew'],
#  ['Si', 'Yuning'],
#  ['Sills', 'Marquis'],
#  ['Sim', 'Su Yong'],
#  ['Sin Ting', 'Toh'],
#  ['Siton', 'Ara Marie'],
#  ['Sitthisirivorakul', 'Jirat'],
#  ['Skinner', 'Garrett'],
#  ['Smith', 'Andrew'],
#  ['Smith', 'Brookelynn'],
#  ['Smith', 'Lauren'],
#  ['Snyder', 'Bennett'],
#  ['Socadagui Casas', 'Elkin Armando'],
#  ['Sofian', 'Felicia'],
#  ['Sohl', 'Dan'],
#  ['Sorensen', 'Brandon'],
#  ['Souza', 'Michelle'],
#  ['Sperry', 'Kenley'],
#  ['Sridharan', 'Ananya'],
#  ['Staines', 'Christopher'],
#  ['Stapp', 'Emma'],
#  ['Stehley', 'Adam'],
#  ['Steiner', 'Kevin'],
#  ['Stimler', 'Charles'],
#  ['Stirrat', 'Matthew'],
#  ['St-Laurent', 'Samuel'],
#  ['Stretch', 'Sinclaire'],
#  ['Strickland', 'Joseph Whitfield'],
#  ['Su', 'Zhanyi'],
#  ['Sugimatsu', 'Takenori'],
#  ['Sun', 'Rachel'],
#  ['Sun', 'Tiancheng'],
#  ['Sun', 'Yan'],
#  ['Suroso', 'Alicia Sophie'],
#  ['Suryanto', 'Kevin'],
#  ['Susu', 'Zheng'],
#  ['Sweeney', 'Megan'],
#  ['Sylvain', 'Roxanne'],
#  ['Szegda', 'Helen'],
#  ['Szpylka', 'Evangeline'],
#  ['Tal', 'Noam'],
#  ['Talbot', 'Noah'],
#  ['Taleb', 'Bouchra'],
#  ['Tam', 'Ho Yin'],
#  ['Tan', 'Highryll'],
#  ['Tan', 'Joana Che Ern'],
#  ['Tang', 'Chi'],
#  ['Tang', 'Linxiao'],
#  ['Tanji', 'Mizuki'],
#  ['Tao', 'Ran'],
#  ['Tating', 'Nicholas'],
#  ['Tausz', 'Alexander'],
#  ['Taylor', 'Andrew'],
#  ['Taylor', 'Jason'],
#  ['Teh', 'Ryan Chong Meng'],
#  ['Teng', 'Shuyi'],
#  ['Tenny', 'Kyle Patrick'],
#  ['Thien Chek Hui', 'Bryan'],
#  ['Thomas', 'Latoya'],
#  ['Thornton', 'Annie'],
#  ['Tiekeu', 'Sirr Landry'],
#  ['Tobwan', 'Sahatep'],
#  ['Tokarsky', 'Alexander'],
#  ['Tolar', 'David'],
#  ['Tolson', 'Anne'],
#  ['Tong', 'Xinying'],
#  ['Tran', 'Nhu'],
#  ['Trehy', 'Kevin'],
#  ['Tremblay', 'Gabriel'],
#  ['Trifillis', 'Maxwell'],
#  ['Tripathi', 'Vinay'],
#  ['Truelock', 'Jack'],
#  ['Truong', 'Florianne'],
#  ['Truong', 'Kha Hong'],
#  ['Tsai', 'Zheng-Xin'],
#  ['Tsogtsaikhan', 'Anudari'],
#  ['Tu', 'Chang'],
#  ['Tupper', 'Kyle'],
#  ['Tweedy', 'Kelsey'],
#  ['Unice', 'Connor'],
#  ['Valencia Bedoya', 'Andres'],
#  ['Valencia', 'William'],
#  ['Valladares', 'Felipe'],
#  ['Vo Thanh', 'Phuong'],
#  ['Vullo', 'Trevor'],
#  ['Walker', 'Alex'],
#  ['Walsh', 'Ryan'],
#  ['Wan', 'Lawrence'],
#  ['Wang', 'Han'],
#  ['Wang', 'Hao-Yuan'],
#  ['Wang', 'Junying'],
#  ['Wang', 'Kejun'],
#  ['Wang', 'Puxuan'],
#  ['Wang', 'Siyu'],
#  ['Wang', 'Wenjing'],
#  ['Wang', 'Xiaolin'],
#  ['Wang', 'Xiaoya'],
#  ['Wang', 'Xixi'],
#  ['Wang', 'Yahao'],
#  ['Wang', 'Yeke'],
#  ['Wang', 'Yingkai'],
#  ['Wang', 'Yisu'],
#  ['Wang', 'Yixin'],
#  ['Wang', 'Yumeng'],
#  ['Wang', 'Zeqi'],
#  ['Watson', 'Brendan'],
#  ['Weber', 'Daniel'],
#  ['Wei', 'Wei'],
#  ['Wei', 'Yu'],
#  ['Weigel', 'Aaron'],
#  ['Wen', 'Yu'],
#  ['Wendeln', 'Josh'],
#  ['Wetzler', 'Harrison'],
#  ['Whelpley', 'Jon'],
#  ['Wilde', 'Nathaniel'],
#  ['Williams', 'Elijah'],
#  ['Williams', 'Triston'],
#  ['Wilson', 'Christopher Lawrence'],
#  ['Wilson', 'Tosha'],
#  ['Winters', 'Amber'],
#  ['Wisor', 'Zane'],
#  ['Wong', 'Chun Keat'],
#  ['Wong', 'Kee Hang'],
#  ['Woodring', 'Alexandra'],
#  ['Wu', 'Eric'],
#  ['Wu', 'Jinlin'],
#  ['Wu', 'Junji'],
#  ['Wu', 'Leilei'],
#  ['Wu', 'Susan'],
#  ['Wu', 'Xiaowei'],
#  ['Wu', 'Xue Ling'],
#  ['Wu', 'Yue'],
#  ['Xian', 'Chulin'],
#  ['Xiao', 'Yufeng'],
#  ['Xinyan', 'Ge'],
#  ['Xiong', 'Xinwei'],
#  ['Xu', 'Chang'],
#  ['Xu', 'Fan'],
#  ['Xu', 'Jia'],
#  ['Xu', 'Jiamin'],
#  ['Xu', 'Jianan'],
#  ['Xu', 'Mengyuan'],
#  ['Xu', 'Ranyi'],
#  ['Xu', 'Shengyao'],
#  ['Xu', 'Shizhou'],
#  ['Xu', 'Su'],
#  ['Xu', 'Xinyu'],
#  ['Xu', 'Yi'],
#  ['Yan', 'Kang'],
#  ['Yang', 'Han'],
#  ['Yang', 'Mingya'],
#  ['Yang', 'Yajie'],
#  ['Yao', 'Lanqiu'],
#  ['Yao', 'Shuoyi'],
#  ['Yap', 'Lawrence Vincent'],
#  ['Ye', 'Chaoqi'],
#  ['Ye', 'Qiang'],
#  ['Ye', 'Zhongsheng'],
#  ['Yeazel', 'Linnea'],
#  ['Yiantsos', 'Andonis'],
#  ['Yin', 'Menghua'],
#  ['Yoo', 'Woongchae'],
#  ['Yoon', 'Hyeongho'],
#  ['Yoon', 'Sung Min'],
#  ['Yoong', 'Nicholas Wen Gen'],
#  ['You', 'Ran'],
#  ['Youn', 'Joshua'],
#  ['Young Hoon', 'Mok'],
#  ['Young', 'Nicholas Ty'],
#  ['Yu', 'Hao-Nien'],
#  ['Yu', 'Lu'],
#  ['Yu', 'Shu San'],
#  ['Yu', 'Xinghua'],
#  ['Yu', 'Xinyi'],
#  ['Yu', 'Yian'],
#  ['Yu', 'Zihan'],
#  ['Yuan', 'Shuhao'],
#  ['Yuan', 'Yu'],
#  ['Yue', 'Sai'],
#  ['Yuen Nee', 'Ng'],
#  ['Yuen', 'Po Yi'],
#  ['Zaborowski', 'Zachary'],
#  ['Zeidan', 'Natalie'],
#  ['Zendejas Limon', 'Cesar'],
#  ['Zhai', 'Yixian'],
#  ['Zhang', 'Dandan'],
#  ['Zhang', 'Hanchun'],
#  ['Zhang', 'Haotian'],
#  ['Zhang', 'Hui'],
#  ['Zhang', 'Jie'],
#  ['Zhang', 'Jin'],
#  ['Zhang', 'Jingyang'],
#  ['Zhang', 'Julie'],
#  ['Zhang', 'Lei'],
#  ['Zhang', 'Mingwei'],
#  ['Zhang', 'Oscar Yong Qi'],
#  ['Zhang', 'Peiyi'],
#  ['Zhang', 'Runze'],
#  ['Zhang', 'Shengning'],
#  ['Zhang', 'Terry'],
#  ['Zhang', 'Weilong'],
#  ['Zhang', 'Xiaofan'],
#  ['Zhang', 'Xin'],
#  ['Zhang', 'Xuefei'],
#  ['Zhang', 'Yilin'],
#  ['Zhang', 'Yuqi'],
#  ['Zhang', 'Ziling'],
#  ['Zhao', 'Dannan'],
#  ['Zhao', 'Min'],
#  ['Zhao', 'Qian'],
#  ['Zhao', 'Ran'],
#  ['Zhao', 'Siyu'],
#  ['Zhao', 'Songqing'],
#  ['Zhao', 'Tianhao'],
#  ['Zhao', 'Wei'],
#  ['Zhao', 'Yuhan'],
#  ['Zhen', 'Yongqi'],
#  ['Zheng', 'Chufan'],
#  ['Zheng', 'Tianxiang'],
#  ['Zhong', 'Haolun'],
#  ['Zhou', 'Jin Hua'],
#  ['Zhou', 'Meihan'],
#  ['Zhou', 'Michael'],
#  ['Zhou', 'Rouhan'],
#  ['Zhou', 'Xiangting'],
#  ['Zhou', 'Yifan'],
#  ['Zhu', 'Beili'],
#  ['Zhu', 'Daping'],
#  ['Zhu', 'Huilin'],
#  ['Zhu', 'Ning'],
#  ['Zhu', 'Ricky'],
#  ['Zhunyang', 'Xu'],
#  ['Ziegelman', 'Dean'],
#  ['Zikpi', 'Christian'],
#  ['Zu', 'Ling']]

# %% [markdown]
# ## Extract From All PDFs and Combine Results

# %%
os.listdir("edu-names-2018_raw") #This is the downloaded zip before we do any cleaning.
# Out:
# ['edu-2018-04-fsa-percents-453he7.pdf',
#  'edu-2018-10-fsa-percents-453hes.pdf',
#  'Exam CFEFD',
#  'Exam CFESDM',
#  'Exam EA1',
#  'Exam EA2F',
#  'Exam EA2L',
#  'Exam ERM',
#  'Exam FM',
#  'Exam GHADV',
#  'Exam GHCORC',
#  'Exam GHCORU',
#  'Exam GHSPC',
#  'Exam GIADV',
#  'Exam GIFREU',
#  'Exam GIINT',
#  'Exam GIIRR',
#  'Exam IFM-MFE',
#  'Exam ILALFVC',
#  'Exam ILALFVU',
#  'Exam ILALP',
#  'Exam ILALRM',
#  'Exam LTAM-MLC',
#  'Exam P',
#  'Exam PA',
#  'Exam QFIADV',
#  'Exam QFICORE',
#  'Exam QFIIRM',
#  'Exam RETDAC',
#  'Exam RETDAU',
#  'Exam RETFRC',
#  'Exam RETRPIRM',
#  'Exam STAM-C',
#  'Exam-SRM']

# %% [markdown]
# Some of the exams changed in 2018 which made the file structure not as nice. We split the "Exam IFM-MFE" exam into folders "Exam IFM" and "Exam MFE" manually. We do the same for "Exam LTAM-MLC" and "Exam STAM-C". We also change "Exam-SRM" to "Exam SRM" for consistency. The described changes are in "edu-names-2018".
#
# We make a list containing the path to every pdf. We scrape every file in the list to get the names of our exam takers.

# %%
examFolders = ["edu-names-2018/" + examPath for examPath in os.listdir("edu-names-2018") if "Exam" in examPath] #Full path for exam folders

examFiles = []
for examFolder in examFolders:
    for resultFile in os.listdir(examFolder):
        if "names" in resultFile:
            examFiles.append(examFolder + "/" + resultFile)

examFiles
# Out:
# ['edu-names-2018/Exam C/edu-2018-02-c-names-ajl65e.pdf',
#  'edu-names-2018/Exam C/edu-2018-06-c-names-afaert6.pdf',
#  'edu-names-2018/Exam CFEFD/edu-2018-04-cfefd-names-je7hd9.pdf',
#  'edu-names-2018/Exam CFEFD/edu-2018-10-cfefd-names-je7hds.pdf',
#  'edu-names-2018/Exam CFESDM/edu-2018-04-cfesdm-names-2de9w0.pdf',
#  'edu-names-2018/Exam CFESDM/edu-2018-11-cfesdm-names-2de9ws.pdf',
#  'edu-names-2018/Exam EA1/edu-2018-05-ea1-names-eeyiuahr8.pdf',
#  'edu-names-2018/Exam EA2F/edu-2018-11-ea2f-names-fiojfe89.pdf',
#  'edu-names-2018/Exam EA2L/edu-2018-05-ea2l-names-jdtyu7.pdf',
#  'edu-names-2018/Exam ERM/edu-2018-04-erm-names-00oe8u.pdf',
#  'edu-names-2018/Exam ERM/edu-2018-10-erm-names-00oe8s.pdf',
#  'edu-names-2018/Exam FM/edu-2018-02-fm-names-lu83jk.pdf',
#  'edu-names-2018/Exam FM/edu-2018-04-fm-names-lhts3ok.pdf',
#  'edu-names-2018/Exam FM/edu-2018-06-fm-names-sujheowihtr.pdf',
#  'edu-names-2018/Exam FM/edu-2018-08-fm-names-6eh88j.pdf',
#  'edu-names-2018/Exam FM/edu-2018-10-fm-names-w47rjknh49.pdf',
#  'edu-names-2018/Exam FM/edu-2018-12-fm-names-dkjhfer78.pdf',
#  'edu-names-2018/Exam GHADV/edu-2018-04-ghadv-names-w6eju9.pdf',
#  'edu-names-2018/Exam GHADV/edu-2018-11-ghadv-names-w6ejus.pdf',
#  'edu-names-2018/Exam GHCORC/edu-2018-04-ghcorc-names-8rk923.pdf',
#  'edu-names-2018/Exam GHCORC/edu-2018-10-ghcorc-names-8rk92d.pdf',
#  'edu-names-2018/Exam GHCORU/edu-2018-04-ghcoru-names-3648jr.pdf',
#  'edu-names-2018/Exam GHCORU/edu-2018-10-ghcoru-names-3648js.pdf',
#  'edu-names-2018/Exam GHSPC/edu-2018-04-ghspc-names-e92k88.pdf',
#  'edu-names-2018/Exam GHSPC/edu-2018-10-ghspc-names-e92k8s.pdf',
#  'edu-names-2018/Exam GIADV/edu-2018-04-giadv-names-qi83jj.pdf',
#  'edu-names-2018/Exam GIADV/edu-2018-10-giadv-names-qi83je.pdf',
#  'edu-names-2018/Exam GIFREU/edu-2018-04-gifreu-names-vc93jn.pdf',
#  'edu-names-2018/Exam GIFREU/edu-2018-11-gifreu-names-vc93je.pdf',
#  'edu-names-2018/Exam GIINT/edu-2018-02-giint-names-sp39qh.pdf',
#  'edu-names-2018/Exam GIINT/edu-2018-05-giint-names-shre65.pdf',
#  'edu-names-2018/Exam GIINT/edu-2018-08-giint-names-wr423t5h.pdf',
#  'edu-names-2018/Exam GIINT/edu-2018-11-giint-names-wr422t5h.pdf',
#  'edu-names-2018/Exam GIIRR/edu-2018-04-giirr-names-kg8uuj.pdf',
#  'edu-names-2018/Exam GIIRR/edu-2018-10-giirr-names-kg8uus.pdf',
#  'edu-names-2018/Exam IFM/edu-2018-07-ifm-names-wfewrtd.pdf',
#  'edu-names-2018/Exam IFM/edu-2018-11-ifm-names-rjhjt84.pdf',
#  'edu-names-2018/Exam ILALFVC/edu-2018-04-ilalfvc-names-84jkw0.pdf',
#  'edu-names-2018/Exam ILALFVC/edu-2018-11-ilalfvc-names-84jkws.pdf',
#  'edu-names-2018/Exam ILALFVU/edu-2018-04-ilalfvu-names-xgs79w.pdf',
#  'edu-names-2018/Exam ILALFVU/edu-2018-11-ilalfvu-names-xgs7es.pdf',
#  'edu-names-2018/Exam ILALP/edu-2018-04-ilalp-names-sa7ejq.pdf',
#  'edu-names-2018/Exam ILALP/edu-2018-10-ilalp-names-sa7ejs.pdf',
#  'edu-names-2018/Exam ILALRM/edu-2018-04-ilalrm-names-dd80dk.pdf',
#  'edu-names-2018/Exam ILALRM/edu-2018-10-ilalrm-names-dd80ds.pdf',
#  'edu-names-2018/Exam LTAM/edu-2018-10-ltam-names-ci03js.pdf',
#  'edu-names-2018/Exam MFE/edu-2018-03-mfe-names-1wae2s.pdf',
#  'edu-names-2018/Exam MLC/edu-2018-04-mlc-names-ci03j8.pdf',
#  'edu-names-2018/Exam P/edu-2018-01-p-names-wdlowd.pdf',
#  'edu-names-2018/Exam P/edu-2018-03-p-names-wsgfdhd.pdf',
#  'edu-names-2018/Exam P/edu-2018-05-p-names-38js03.pdf',
#  'edu-names-2018/Exam P/edu-2018-07-p-names-hiughd.pdf',
#  'edu-names-2018/Exam P/edu-2018-09-p-names-wdfewet.pdf',
#  'edu-names-2018/Exam P/edu-2018-11-p-names-wdfewes.pdf',
#  'edu-names-2018/Exam PA/edu-2018-12-pa-names-wyu7t9f.pdf',
#  'edu-names-2018/Exam QFIADV/edu-2018-04-qfiadv-names-cy0kee.pdf',
#  'edu-names-2018/Exam QFIADV/edu-2018-11-qfiadv-names-cy0kes.pdf',
#  'edu-names-2018/Exam QFICORE/edu-2018-04-qficore-names-zh376v.pdf',
#  'edu-names-2018/Exam QFICORE/edu-2018-10-qficore-names-zh376s.pdf',
#  'edu-names-2018/Exam QFIIRM/edu-2018-04-qfiirm-names-ff9ekp.pdf',
#  'edu-names-2018/Exam QFIIRM/edu-2018-10-qfiirm-names-ff9eks.pdf',
#  'edu-names-2018/Exam RETDAC/edu-2018-04-retdac-names-pff3je.pdf',
#  'edu-names-2018/Exam RETDAC/edu-2018-11-retdac-names-pff3js.pdf',
#  'edu-names-2018/Exam RETDAU/edu-2018-04-retdau-names-bh3jr9.pdf',
#  'edu-names-2018/Exam RETDAU/edu-2018-11-retdau-names-bh3jrp.pdf',
#  'edu-names-2018/Exam RETFRC/edu-2018-04-retfrc-names-655y48.pdf',
#  'edu-names-2018/Exam RETFRC/edu-2018-10-retfrc-names-655y4s.pdf',
#  'edu-names-2018/Exam RETRPIRM/edu-2018-04-retrpirm-names-nnbd90.pdf',
#  'edu-names-2018/Exam RETRPIRM/edu-2018-10-retrpirm-names-nnbd9s.pdf',
#  'edu-names-2018/Exam SRM/edu-2018-09-srm-names-fhnhbfr8.pdf',
#  'edu-names-2018/Exam STAM/edu-2018-10-stam-names-fbj35fgv.pdf']

# %% [markdown]
# We scrape every name in every file and add it to a list. We use the file paths to fill in information for which exam was passed and when it was passed.

# %%
regexExamName = re.compile(r'Exam\s[A-Z]*')
regexDate = re.compile(r'[0-9]{4}-[0-9]{2}')

allNames = []
for file in examFiles:
    examInfo = regexExamName.search(file).group()
    monthInfo = regexDate.search(file).group()
    rawNames = scrapeNames(file)
    formattedNames = [formatName(name) for name in rawNames]
    for name in formattedNames:
        allNames.append([name[0], name[1], examInfo, monthInfo])
allNames
# Out:
# [['Ab Manan', 'Muhd Azman Firdaus', 'Exam C', '2018-02'],
#  ['Abadeer', 'Mirette', 'Exam C', '2018-02'],
#  ['Abbott', 'Anthony', 'Exam C', '2018-02'],
#  ['Abramova', 'Rena', 'Exam C', '2018-02'],
#  ['Adair', 'Liam Alexander', 'Exam C', '2018-02'],
#  ['Adams', 'Brooke', 'Exam C', '2018-02'],
#  ['Adler', 'Justin', 'Exam C', '2018-02'],
#  ['Agcaoili', 'Ramon Vicente Rimando', 'Exam C', '2018-02'],
#  ['Ahmad', 'Osman', 'Exam C', '2018-02'],
#  ['Akoto', 'Osei', 'Exam C', '2018-02'],
#  ['Allen', 'Austin Sei', 'Exam C', '2018-02'],
#  ['Allen', 'Dina', 'Exam C', '2018-02'],
#  ['Al-Yassin', 'Julan', 'Exam C', '2018-02'],
#  ['Amabile', 'Devan Rose', 'Exam C', '2018-02'],
#  ['Amador', 'Daisy Margarita', 'Exam C', '2018-02'],
#  ['Aman', 'Eric J', 'Exam C', '2018-02'],
#  ['Amburgey', 'Stephen', 'Exam C', '2018-02'],
#  ['Amoh', 'Ebenezer', 'Exam C', '2018-02'],
#  ['Amponsah', 'Charles Kwame', 'Exam C', '2018-02'],
#  ['An', 'Zuoni', 'Exam C', '2018-02'],
#  ['Anderson', 'Emilie', 'Exam C', '2018-02'],
#  ['Anderson', 'Marshall Wilson', 'Exam C', '2018-02'],
#  ['Andrew', 'Kevin', 'Exam C', '2018-02'],
#  ['Andrews', 'Hannah', 'Exam C', '2018-02'],
#  ['Andryski', 'Heather Leigh', 'Exam C', '2018-02'],
#  ['Angiolelli', 'Gabrielle Megan', 'Exam C', '2018-02'],
#  ['Araniyasundaran', 'Julie', 'Exam C', '2018-02'],
#  ['Au', 'Aleena Hoi Yen', 'Exam C', '2018-02'],
#  ['Augspurger', 'Caleb', 'Exam C', '2018-02'],
#  ['Babb', 'Sonya Anita', 'Exam C', '2018-02'],
#  ['Bachman', 'Timothy James', 'Exam C', '2018-02'],
#  ['Backer', 'Bridget Cecilia', 'Exam C', '2018-02'],
#  ['Bae', 'Jun Hwan', 'Exam C', '2018-02'],
#  ['Bagan', 'Patrick Michael', 'Exam C', '2018-02'],
#  ['Bai', 'Ziyou', 'Exam C', '2018-02'],
#  ['Baidolotova', 'Zharkynai', 'Exam C', '2018-02'],
#  ['Balan', 'Carina', 'Exam C', '2018-02'],
#  ['Baldauf', 'Cody', 'Exam C', '2018-02'],
#  ['Bali', 'Manisha', 'Exam C', '2018-02'],
#  ['Baran', 'Hayley Anne Elizabeth', 'Exam C', '2018-02'],
#  ['Barker', 'Alexandra', 'Exam C', '2018-02'],
#  ['Barnes', 'Kenda', 'Exam C', '2018-02'],
#  ['Bayou', 'Sofiane', 'Exam C', '2018-02'],
#  ['Beach', 'Charlotte', 'Exam C', '2018-02'],
#  ['Beatty', 'Alexander Lorne Kenneth', 'Exam C', '2018-02'],
#  ['Beauparlant', 'Jordan', 'Exam C', '2018-02'],
#  ['Beckham', 'Steven', 'Exam C', '2018-02'],
#  ['Beckley', 'Jenna', 'Exam C', '2018-02'],
#  ['Belanger', 'Chad', 'Exam C', '2018-02'],
#  ['Béliveau', 'Marie-Christine', 'Exam C', '2018-02'],
#  ['Bello', 'Alexsandra', 'Exam C', '2018-02'],
#  ['Benoit', 'Jacob', 'Exam C', '2018-02'],
#  ['Bergin', 'Jacob Owen', 'Exam C', '2018-02'],
#  ['Bermke', 'Samuel', 'Exam C', '2018-02'],
#  ['Berry', 'Kayla', 'Exam C', '2018-02'],
#  ['Bertolo', 'Avery', 'Exam C', '2018-02'],
#  ['Bertsch', 'Lukas', 'Exam C', '2018-02'],
#  ['Bevins', 'Thomas Joseph', 'Exam C', '2018-02'],
#  ['Biernat', 'Krista', 'Exam C', '2018-02'],
#  ['Bilton', 'Ryan', 'Exam C', '2018-02'],
#  ['Bingo', 'Hayato', 'Exam C', '2018-02'],
#  ['Bishop', 'Duncan', 'Exam C', '2018-02'],
#  ['Bistolarides', 'Paul', 'Exam C', '2018-02'],
#  ['Bixby', 'Tyler Martin', 'Exam C', '2018-02'],
#  ['Block', 'Eric', 'Exam C', '2018-02'],
#  ['Bloom', 'Nicholas', 'Exam C', '2018-02'],
#  ['Bloom', 'Shannon', 'Exam C', '2018-02'],
#  ['Boamah-Addo', 'Kwame', 'Exam C', '2018-02'],
#  ['Bobart', 'Toni-Marie', 'Exam C', '2018-02'],
#  ['Boegel', 'Paul', 'Exam C', '2018-02'],
#  ['Boily', 'Gabriel', 'Exam C', '2018-02'],
#  ['Bonasera', 'Nicholas', 'Exam C', '2018-02'],
#  ['Bonner', 'Catherine Jean', 'Exam C', '2018-02'],
#  ['Bonneville', 'Sabrina', 'Exam C', '2018-02'],
#  ['Bonny', 'James', 'Exam C', '2018-02'],
#  ['Borden', 'Amanda Lyn', 'Exam C', '2018-02'],
#  ['Bouc', 'Jason', 'Exam C', '2018-02'],
#  ['Boyle', 'Jarryd C', 'Exam C', '2018-02'],
#  ['Braam', 'Grant', 'Exam C', '2018-02'],
#  ['Brady', 'Matthew', 'Exam C', '2018-02'],
#  ['Brennan', 'Paul', 'Exam C', '2018-02'],
#  ['Bressler', 'David', 'Exam C', '2018-02'],
#  ['Briand-Carle', 'Julie', 'Exam C', '2018-02'],
#  ['Brodsky', 'Binyomin', 'Exam C', '2018-02'],
#  ['Brown', 'David Michael', 'Exam C', '2018-02'],
#  ['Brown', 'Samuel Juk-Ping', 'Exam C', '2018-02'],
#  ['Brown', 'Stephen', 'Exam C', '2018-02'],
#  ['Brown', 'Veronica', 'Exam C', '2018-02'],
#  ['Brownson', 'Michael Scott', 'Exam C', '2018-02'],
#  ['Brus', 'Shawn', 'Exam C', '2018-02'],
#  ['Buda', 'Sergiu Sorin', 'Exam C', '2018-02'],
#  ['Bulatova', 'Natalia', 'Exam C', '2018-02'],
#  ['Buness', 'Alicia Nichole', 'Exam C', '2018-02'],
#  ['Bunevich', 'Carrie', 'Exam C', '2018-02'],
#  ['Burke', 'Kathryn', 'Exam C', '2018-02'],
#  ['Burkett', 'Brad Steven', 'Exam C', '2018-02'],
#  ['Burkinshaw', 'Jeremy', 'Exam C', '2018-02'],
#  ['Burney', 'Douglas', 'Exam C', '2018-02'],
#  ['Burns', 'Sean', 'Exam C', '2018-02'],
#  ['Bush', 'Garrett Louis', 'Exam C', '2018-02'],
#  ['Byun', 'Jiwook', 'Exam C', '2018-02'],
#  ['Cade', 'Cassidie Jean', 'Exam C', '2018-02'],
#  ['Cai', 'Andrew', 'Exam C', '2018-02'],
#  ['Cai', 'Lize', 'Exam C', '2018-02'],
#  ['Cai', 'Ruo Lin', 'Exam C', '2018-02'],
#  ['Cai', 'Wanqing', 'Exam C', '2018-02'],
#  ['Cai', 'Wenlan', 'Exam C', '2018-02'],
#  ['Caillé-Morneau', 'Alexandre', 'Exam C', '2018-02'],
#  ['Caito', 'Caley', 'Exam C', '2018-02'],
#  ['Calderon', 'Benjamin', 'Exam C', '2018-02'],
#  ['Cale', 'Scott Carlton Walter', 'Exam C', '2018-02'],
#  ['Cameron', 'Daniel Andrew', 'Exam C', '2018-02'],
#  ['Campbell', 'Hamid', 'Exam C', '2018-02'],
#  ['Canfield', 'Michael', 'Exam C', '2018-02'],
#  ['Cannon', 'Carter Mason', 'Exam C', '2018-02'],
#  ['Carey', 'Shayla Marie', 'Exam C', '2018-02'],
#  ['Carr', 'Andrew Robert', 'Exam C', '2018-02'],
#  ['Carver', 'Tory', 'Exam C', '2018-02'],
#  ['Casalla', 'Kyle', 'Exam C', '2018-02'],
#  ['Chaiprasopphon', 'Chatchai', 'Exam C', '2018-02'],
#  ['Chammas', 'Daniel', 'Exam C', '2018-02'],
#  ['Chan', 'Chi Yiu', 'Exam C', '2018-02'],
#  ['Chan', 'Chung Yan', 'Exam C', '2018-02'],
#  ['Chan', 'Dick Nam Hei', 'Exam C', '2018-02'],
#  ['Chan', 'Hoi Yin', 'Exam C', '2018-02'],
#  ['Chan', 'Ja Sen', 'Exam C', '2018-02'],
#  ['Chan', 'Richard', 'Exam C', '2018-02'],
#  ['Chan', 'Yuenha', 'Exam C', '2018-02'],
#  ['Chang', 'Chris', 'Exam C', '2018-02'],
#  ['Chang', 'Terrance Timothy', 'Exam C', '2018-02'],
#  ['Charef', 'Sarah', 'Exam C', '2018-02'],
#  ['Chatterjee', 'Akash', 'Exam C', '2018-02'],
#  ['Chau', 'Kin Ching Lydia', 'Exam C', '2018-02'],
#  ['Chau', 'Man Leuk', 'Exam C', '2018-02'],
#  ['Chau', 'Wah Chun', 'Exam C', '2018-02'],
#  ['Chen', 'Chun-Yi', 'Exam C', '2018-02'],
#  ['Chen', 'Hillary', 'Exam C', '2018-02'],
#  ['Chen', 'Hongxi', 'Exam C', '2018-02'],
#  ['Chen', 'I-Hua', 'Exam C', '2018-02'],
#  ['Chen', 'Shilin', 'Exam C', '2018-02'],
#  ['Chen', 'Tran-Yuan', 'Exam C', '2018-02'],
#  ['Chen', 'Xinyu', 'Exam C', '2018-02'],
#  ['Chen', 'Xinyuan', 'Exam C', '2018-02'],
#  ['Chen', 'Yanjun', 'Exam C', '2018-02'],
#  ['Chen', 'Yanliang', 'Exam C', '2018-02'],
#  ['Chen', 'Yi An', 'Exam C', '2018-02'],
#  ['Chen', 'Yongyang', 'Exam C', '2018-02'],
#  ['Chen', 'Zhi', 'Exam C', '2018-02'],
#  ['Chenard', 'Pierre', 'Exam C', '2018-02'],
#  ['Cheng', 'Billy', 'Exam C', '2018-02'],
#  ['Cheng', 'Pei Yu', 'Exam C', '2018-02'],
#  ['Cheong', 'Wei Feng', 'Exam C', '2018-02'],
#  ['Chervinski', 'Rebecca', 'Exam C', '2018-02'],
#  ['Chesser', 'Kylie Lynn', 'Exam C', '2018-02'],
#  ['Cheung', 'Ching Yin', 'Exam C', '2018-02'],
#  ['Cheung', 'Ka Leung Godfrey', 'Exam C', '2018-02'],
#  ['Cheung', 'On Tung', 'Exam C', '2018-02'],
#  ['Chew', 'Jianxun', 'Exam C', '2018-02'],
#  ['Chiam Huiqin', 'Amos', 'Exam C', '2018-02'],
#  ['Chien', 'Phoebe', 'Exam C', '2018-02'],
#  ['Chiong', 'Zhe Hui', 'Exam C', '2018-02'],
#  ['Chipman', 'Elizabeth', 'Exam C', '2018-02'],
#  ['Chiu', 'Man Lung', 'Exam C', '2018-02'],
#  ['Cho', 'Seulgi', 'Exam C', '2018-02'],
#  ['Choi', 'Hana', 'Exam C', '2018-02'],
#  ['Choi', 'Wang Hei', 'Exam C', '2018-02'],
#  ['Choi', 'Won Seok', 'Exam C', '2018-02'],
#  ['Chong', 'Desmond', 'Exam C', '2018-02'],
#  ['Choucair', 'Marianne', 'Exam C', '2018-02'],
#  ['Choudhury', 'Rohini', 'Exam C', '2018-02'],
#  ['Chrisman', 'Lauren Nikita', 'Exam C', '2018-02'],
#  ['Christensen', 'Jeremy Keller', 'Exam C', '2018-02'],
#  ['Christensen', 'Kyle Joseph', 'Exam C', '2018-02'],
#  ['Chung', 'Xin Yi', 'Exam C', '2018-02'],
#  ['Cirasa', 'Matthew', 'Exam C', '2018-02'],
#  ['Clark', 'Ryan', 'Exam C', '2018-02'],
#  ['Cloe', 'Adam', 'Exam C', '2018-02'],
#  ['Codey', 'Brandon Edward', 'Exam C', '2018-02'],
#  ['Coon', 'James', 'Exam C', '2018-02'],
#  ['Copeland', 'Phillip W.', 'Exam C', '2018-02'],
#  ['Corbeil', 'Marc Alain', 'Exam C', '2018-02'],
#  ['Costa', 'Stephen', 'Exam C', '2018-02'],
#  ['Cotter', 'John Joseph', 'Exam C', '2018-02'],
#  ['Cottrell', 'Nicholas Adam', 'Exam C', '2018-02'],
#  ['Coussa', 'Victoria', 'Exam C', '2018-02'],
#  ['Craig', 'Daniel', 'Exam C', '2018-02'],
#  ['Crumrine', 'Jessica', 'Exam C', '2018-02'],
#  ['Crutchfield', 'Danyelle Geneva', 'Exam C', '2018-02'],
#  ['Cui', 'Yizhou', 'Exam C', '2018-02'],
#  ['Cui', 'Yuexing', 'Exam C', '2018-02'],
#  ['Cui', 'Zhongdi', 'Exam C', '2018-02'],
#  ['Cuoci', 'Alexandre', 'Exam C', '2018-02'],
#  ['Curran', 'Katherine', 'Exam C', '2018-02'],
#  ['Dalrymple', 'Kezia Mesha Margaret', 'Exam C', '2018-02'],
#  ['Dang', 'Vincent Tieu', 'Exam C', '2018-02'],
#  ['Daniere', 'Adam Zyad', 'Exam C', '2018-02'],
#  ['Darwish', 'Sara', 'Exam C', '2018-02'],
#  ['Dauerer', 'Erin', 'Exam C', '2018-02'],
#  ['Davis', 'Austin', 'Exam C', '2018-02'],
#  ['Dean', 'John', 'Exam C', '2018-02'],
#  ['Defuria', 'Dominic', 'Exam C', '2018-02'],
#  ['DeKnight', 'Harrison Phillip', 'Exam C', '2018-02'],
#  ['del Rosario', 'Arvin Jason', 'Exam C', '2018-02'],
#  ['Dela Cruz', 'Jasmine Isabelle', 'Exam C', '2018-02'],
#  ['DeLuzio', 'Justin Anthony', 'Exam C', '2018-02'],
#  ['Deng', 'Zhiyan', 'Exam C', '2018-02'],
#  ['DeNoyer', 'Andrew Michael', 'Exam C', '2018-02'],
#  ['Der', 'Linda', 'Exam C', '2018-02'],
#  ['Di Schiavi', 'Joseph', 'Exam C', '2018-02'],
#  ['DiCillo', 'Stephen', 'Exam C', '2018-02'],
#  ['Diebold', 'Nicole', 'Exam C', '2018-02'],
#  ['Dieckelman', 'Laura', 'Exam C', '2018-02'],
#  ['Digregorio', 'Jessica', 'Exam C', '2018-02'],
#  ['Dillemuth', 'Mark', 'Exam C', '2018-02'],
#  ['DiMauro', 'Jason Thomas', 'Exam C', '2018-02'],
#  ['Ding', 'Chenyue', 'Exam C', '2018-02'],
#  ['Ding', 'Zhuoyu', 'Exam C', '2018-02'],
#  ['Disanayaka', 'Peshala', 'Exam C', '2018-02'],
#  ['Djouder', 'Redouane', 'Exam C', '2018-02'],
#  ['Djuvik', 'Kimberly', 'Exam C', '2018-02'],
#  ['Dockendorf', 'Tristan Arthur', 'Exam C', '2018-02'],
#  ['Domínguez', 'Ricardo Miguel', 'Exam C', '2018-02'],
#  ['Dong', 'Yanwu', 'Exam C', '2018-02'],
#  ['Dowell', 'Frederick Thomas', 'Exam C', '2018-02'],
#  ['Du', 'Zhenxiao', 'Exam C', '2018-02'],
#  ['Duan', 'Qi', 'Exam C', '2018-02'],
#  ['Duqum', 'Andrew', 'Exam C', '2018-02'],
#  ['Durner', 'Sean Michael', 'Exam C', '2018-02'],
#  ['Duxbury', 'Andrew', 'Exam C', '2018-02'],
#  ['Ellie', 'Quentin John', 'Exam C', '2018-02'],
#  ['Endo', 'Jessica', 'Exam C', '2018-02'],
#  ['Eom', 'Taeyun', 'Exam C', '2018-02'],
#  ['Fairbairn', 'Cutler', 'Exam C', '2018-02'],
#  ['Falgares', 'Joseph C.', 'Exam C', '2018-02'],
#  ['Falzone', 'Christian', 'Exam C', '2018-02'],
#  ['Fan', 'Naifu', 'Exam C', '2018-02'],
#  ['Fan', 'Qi', 'Exam C', '2018-02'],
#  ['Fan', 'Tsz Chung', 'Exam C', '2018-02'],
#  ['Fandacone', 'Anthony Thomas', 'Exam C', '2018-02'],
#  ['Fang', 'Rui', 'Exam C', '2018-02'],
#  ['Fang', 'Thomas Yu-Chen', 'Exam C', '2018-02'],
#  ['Fann', 'Sin-Yin', 'Exam C', '2018-02'],
#  ['Faparusi', 'Adetokunbo', 'Exam C', '2018-02'],
#  ['Fardy', 'Nicole', 'Exam C', '2018-02'],
#  ['Feng', 'Cuiyin', 'Exam C', '2018-02'],
#  ['Feng', 'Lin', 'Exam C', '2018-02'],
#  ['Feng', 'Manyao', 'Exam C', '2018-02'],
#  ['Ferens', 'Adrian', 'Exam C', '2018-02'],
#  ['Fernandez', 'Carlos', 'Exam C', '2018-02'],
#  ['Fesser', 'Adrian Julio', 'Exam C', '2018-02'],
#  ['Filintas Wiratama', 'Endy', 'Exam C', '2018-02'],
#  ['Findlan', 'Robert', 'Exam C', '2018-02'],
#  ['Finn', 'Grant Daniel', 'Exam C', '2018-02'],
#  ['Fishter', 'Jake', 'Exam C', '2018-02'],
#  ['Fitzpatrick', 'Benjamin', 'Exam C', '2018-02'],
#  ['Flood', 'Brian Thomas', 'Exam C', '2018-02'],
#  ['Fountain', 'Justin A', 'Exam C', '2018-02'],
#  ['Frederick', 'Ethan', 'Exam C', '2018-02'],
#  ['Frederickson', 'Nicole', 'Exam C', '2018-02'],
#  ['Frentzas', 'Basilios', 'Exam C', '2018-02'],
#  ['Fruth', 'Paul Michael', 'Exam C', '2018-02'],
#  ['Fu', 'Zhongyi', 'Exam C', '2018-02'],
#  ['Fung', 'Man Ki Maggie', 'Exam C', '2018-02'],
#  ['Furman', 'Mackenzie', 'Exam C', '2018-02'],
#  ['Gagnon', 'Jonathan', 'Exam C', '2018-02'],
#  ['Galiano', 'William Alister', 'Exam C', '2018-02'],
#  ['Gantz', 'Tracy Lynn', 'Exam C', '2018-02'],
#  ['Gao', 'Yufeng', 'Exam C', '2018-02'],
#  ['Gao', 'Zhongyi', 'Exam C', '2018-02'],
#  ['Garcia', 'Jeremy Vaughn', 'Exam C', '2018-02'],
#  ['Gates', 'Robert Alan', 'Exam C', '2018-02'],
#  ['Gatta', 'Carmen Vincent', 'Exam C', '2018-02'],
#  ['Gavetti', 'Nicole Rose', 'Exam C', '2018-02'],
#  ['Ge', 'Jiachen', 'Exam C', '2018-02'],
#  ['Gerber', 'Daniel', 'Exam C', '2018-02'],
#  ['Germain', 'Andrew', 'Exam C', '2018-02'],
#  ['Giardina', 'Ariana', 'Exam C', '2018-02'],
#  ['Giblin', 'Matthew', 'Exam C', '2018-02'],
#  ['Giletto', 'Nicole Madelyn', 'Exam C', '2018-02'],
#  ['Gilmour', 'Samuel', 'Exam C', '2018-02'],
#  ['Gim', 'Yeong Ung', 'Exam C', '2018-02'],
#  ['Giordano', 'Alexander', 'Exam C', '2018-02'],
#  ['Giovanni', 'Jose', 'Exam C', '2018-02'],
#  ['Glicksman', 'Robert', 'Exam C', '2018-02'],
#  ['Glod', 'Inga', 'Exam C', '2018-02'],
#  ['Goddu', 'Brian Robert', 'Exam C', '2018-02'],
#  ['Godin-Perron', 'Léonie', 'Exam C', '2018-02'],
#  ['Goetz', 'Shannon', 'Exam C', '2018-02'],
#  ['Gordon', 'Jesse', 'Exam C', '2018-02'],
#  ['Gordon', 'Kenneth', 'Exam C', '2018-02'],
#  ['Gorgan', 'Keri', 'Exam C', '2018-02'],
#  ['Gorski', 'Michael C.', 'Exam C', '2018-02'],
#  ['Graham', 'Christopher Ryan', 'Exam C', '2018-02'],
#  ['Grangruth', 'Brandon', 'Exam C', '2018-02'],
#  ['Grant', 'Sheniele Marie Anahva', 'Exam C', '2018-02'],
#  ['Grewal', 'Herman', 'Exam C', '2018-02'],
#  ['Grieco', 'Nicole', 'Exam C', '2018-02'],
#  ['Griffith', 'Brett', 'Exam C', '2018-02'],
#  ['Grossi', 'Tyler', 'Exam C', '2018-02'],
#  ['Gu', 'Jielei', 'Exam C', '2018-02'],
#  ['Gu', 'Yelei', 'Exam C', '2018-02'],
#  ['Guan', 'Liyan', 'Exam C', '2018-02'],
#  ['Guinee', 'Molly R', 'Exam C', '2018-02'],
#  ['Guo', 'Jiahuan', 'Exam C', '2018-02'],
#  ['Guo', 'Jingyi', 'Exam C', '2018-02'],
#  ['Guo', 'Xiaojun', 'Exam C', '2018-02'],
#  ['Guo', 'Yajing', 'Exam C', '2018-02'],
#  ['Gutierrez', 'Bryana Yereida', 'Exam C', '2018-02'],
#  ['Gwinner', 'Austin Lee', 'Exam C', '2018-02'],
#  ['Hable', 'Courtney', 'Exam C', '2018-02'],
#  ['Hachem', 'Dalia Jean-Claude', 'Exam C', '2018-02'],
#  ['Hague', 'Kyle Robert', 'Exam C', '2018-02'],
#  ['Hallberg', 'Benjamin', 'Exam C', '2018-02'],
#  ['Han', 'Gun Hee', 'Exam C', '2018-02'],
#  ['Han', 'Jiyoun', 'Exam C', '2018-02'],
#  ['Han', 'Zimo', 'Exam C', '2018-02'],
#  ['Hang', 'Eric', 'Exam C', '2018-02'],
#  ['Hanson', 'Brent', 'Exam C', '2018-02'],
#  ['Hanson', 'Brian', 'Exam C', '2018-02'],
#  ['Hart', 'Samantha', 'Exam C', '2018-02'],
#  ['Haug', 'Joshua Ryan', 'Exam C', '2018-02'],
#  ['Hauptmann', 'Nicholas', 'Exam C', '2018-02'],
#  ['Hayes', 'Andrew', 'Exam C', '2018-02'],
#  ['Hayes', 'Joseph Franklin', 'Exam C', '2018-02'],
#  ['Hayes', 'Maris', 'Exam C', '2018-02'],
#  ['He', 'Jerry', 'Exam C', '2018-02'],
#  ['Heether', 'David', 'Exam C', '2018-02'],
#  ['Hehir', 'Sam', 'Exam C', '2018-02'],
#  ['Heiden', 'Matthew', 'Exam C', '2018-02'],
#  ['Heimlich', 'Andrew', 'Exam C', '2018-02'],
#  ['Heinlein', 'Sara', 'Exam C', '2018-02'],
#  ['Henehan', 'William Joseph', 'Exam C', '2018-02'],
#  ['Henry', 'James', 'Exam C', '2018-02'],
#  ['Herbstman', 'Leah', 'Exam C', '2018-02'],
#  ['Hickman', 'John Michael', 'Exam C', '2018-02'],
#  ['Hiebner', 'Lance', 'Exam C', '2018-02'],
#  ['Hill', 'David Kramer', 'Exam C', '2018-02'],
#  ['Hines', 'Ryan', 'Exam C', '2018-02'],
#  ['Ho', 'Anh Thai', 'Exam C', '2018-02'],
#  ['Ho', 'Hei Shun Matthew', 'Exam C', '2018-02'],
#  ['Ho', 'Kar Men', 'Exam C', '2018-02'],
#  ['Ho', 'Meng-Ju', 'Exam C', '2018-02'],
#  ['Hobbs', 'Nicole Marie', 'Exam C', '2018-02'],
#  ['Hobein', 'Jason Frank', 'Exam C', '2018-02'],
#  ['Hodge', 'Emrith', 'Exam C', '2018-02'],
#  ['Hoffer', 'Richard John', 'Exam C', '2018-02'],
#  ['Hoffman', 'Kristen', 'Exam C', '2018-02'],
#  ['Hogan', 'Michael', 'Exam C', '2018-02'],
#  ['Hoke', 'Chad', 'Exam C', '2018-02'],
#  ['Holtz', 'Matthew', 'Exam C', '2018-02'],
#  ['Hong Zhe', 'Ng', 'Exam C', '2018-02'],
#  ['Hong', 'Harry Il Suk', 'Exam C', '2018-02'],
#  ['Honken', 'Annette', 'Exam C', '2018-02'],
#  ['Hoopengardner', 'Shanna Rochelle', 'Exam C', '2018-02'],
#  ['Hopkins', 'Gabriel', 'Exam C', '2018-02'],
#  ['Horas', 'Matthew Robert', 'Exam C', '2018-02'],
#  ['Horton', 'Kylie', 'Exam C', '2018-02'],
#  ['Howes', 'Heather Rachel', 'Exam C', '2018-02'],
#  ['Hsu', 'Hsin-Haw', 'Exam C', '2018-02'],
#  ['Hu', 'David', 'Exam C', '2018-02'],
#  ['Hu', 'Hongbo', 'Exam C', '2018-02'],
#  ['Hu', 'Mingyi', 'Exam C', '2018-02'],
#  ['Hua', 'Lu', 'Exam C', '2018-02'],
#  ['Huang', 'Minfan', 'Exam C', '2018-02'],
#  ['Huang', 'Tzu Yu', 'Exam C', '2018-02'],
#  ['Huang', 'Yichun', 'Exam C', '2018-02'],
#  ['Hucaluk', 'Dennis', 'Exam C', '2018-02'],
#  ['Hui', 'Chi Hang', 'Exam C', '2018-02'],
#  ['Hui', 'Ka Wun', 'Exam C', '2018-02'],
#  ['Huisinga', 'Scott Thomas Milford', 'Exam C', '2018-02'],
#  ['Hwang', 'Eric', 'Exam C', '2018-02'],
#  ['Hwang', 'Sangmun', 'Exam C', '2018-02'],
#  ['Hyeri', 'Yoo', 'Exam C', '2018-02'],
#  ['Hyman', 'Rachel', 'Exam C', '2018-02'],
#  ['Hyun', 'Seunghan', 'Exam C', '2018-02'],
#  ['Impellizzeri', 'Philip', 'Exam C', '2018-02'],
#  ['Irlmeier', 'Amber', 'Exam C', '2018-02'],
#  ['Itthithumsakul', 'Krittapol', 'Exam C', '2018-02'],
#  ['Jacobson', 'Steven James', 'Exam C', '2018-02'],
#  ['Jacques', 'Kéven', 'Exam C', '2018-02'],
#  ['Jaffe', 'Derek Scott', 'Exam C', '2018-02'],
#  ['Jakes', 'Peter Lawrence', 'Exam C', '2018-02'],
#  ['Jamaludin', 'Firdaus Hafizi Bin', 'Exam C', '2018-02'],
#  ['Janecek', 'Benjamin', 'Exam C', '2018-02'],
#  ['Jang', 'Yohan', 'Exam C', '2018-02'],
#  ['Jee', 'Hyun Ho', 'Exam C', '2018-02'],
#  ['Jensen', 'Andrew', 'Exam C', '2018-02'],
#  ['Jeon', 'Sangmin', 'Exam C', '2018-02'],
#  ['Jeong', 'Ung', 'Exam C', '2018-02'],
#  ['Jeong', 'Yun-Chang', 'Exam C', '2018-02'],
#  ['Jhee', 'Jeffrey Tudtud', 'Exam C', '2018-02'],
#  ['Ji', 'Xiaomeng', 'Exam C', '2018-02'],
#  ['Jia', 'Houxiang', 'Exam C', '2018-02'],
#  ['Jia', 'Ruofan', 'Exam C', '2018-02'],
#  ['Jian', 'Dawei', 'Exam C', '2018-02'],
#  ['Jiang', 'Anqi', 'Exam C', '2018-02'],
#  ['Jiang', 'Linshan', 'Exam C', '2018-02'],
#  ['Jiang', 'Na', 'Exam C', '2018-02'],
#  ['Jiang', 'Piao', 'Exam C', '2018-02'],
#  ['Jiang', 'Tian', 'Exam C', '2018-02'],
#  ['Jiang', 'Ya Fan', 'Exam C', '2018-02'],
#  ['Jiang', 'Yi', 'Exam C', '2018-02'],
#  ['Jin', 'Sunhak', 'Exam C', '2018-02'],
#  ['Jin', 'Xin', 'Exam C', '2018-02'],
#  ['Jing', 'Yu', 'Exam C', '2018-02'],
#  ['Johnson', 'Ben', 'Exam C', '2018-02'],
#  ['Johnson', 'Benjamin', 'Exam C', '2018-02'],
#  ['Johnson', 'Derek Steven', 'Exam C', '2018-02'],
#  ['Johnson', 'Hariz', 'Exam C', '2018-02'],
#  ['Jones', 'Nicole', 'Exam C', '2018-02'],
#  ['Jones', 'Sarah Regina', 'Exam C', '2018-02'],
#  ['Joo', 'Woohyun', 'Exam C', '2018-02'],
#  ['Joshi', 'Ayush', 'Exam C', '2018-02'],
#  ['Judson', 'Matthew', 'Exam C', '2018-02'],
#  ['Jung', 'Eunju', 'Exam C', '2018-02'],
#  ['Justo', 'Allison', 'Exam C', '2018-02'],
#  ['Kagan', 'Michael', 'Exam C', '2018-02'],
#  ['Kah Wai', 'Liang', 'Exam C', '2018-02'],
#  ['Kamireddipalli', 'Sreekaavya', 'Exam C', '2018-02'],
#  ['Kamka', 'Daniel Thomas', 'Exam C', '2018-02'],
#  ['Kandoje', 'Pemphero David', 'Exam C', '2018-02'],
#  ['Kang', 'Hsin-Ting', 'Exam C', '2018-02'],
#  ['Kang', 'Minjae', 'Exam C', '2018-02'],
#  ['Kang', 'Namhee', 'Exam C', '2018-02'],
#  ['Kang', 'Xiaoran', 'Exam C', '2018-02'],
#  ['Kantatasiri', 'Torfun', 'Exam C', '2018-02'],
#  ['Karani', 'Shivani', 'Exam C', '2018-02'],
#  ['Kathirchelvan', 'Bakeeshan', 'Exam C', '2018-02'],
#  ['Kaus', 'Zachary', 'Exam C', '2018-02'],
#  ['Keenan', 'Kelsey Rebecca', 'Exam C', '2018-02'],
#  ['Keeratibharat', 'Suksa', 'Exam C', '2018-02'],
#  ['Kelley', 'Connor', 'Exam C', '2018-02'],
#  ['Kelley', 'William Martin', 'Exam C', '2018-02'],
#  ['Kelly', 'Angelina M', 'Exam C', '2018-02'],
#  ['Keppen', 'Matthew', 'Exam C', '2018-02'],
#  ['Kepple Chancey', 'Jennifer', 'Exam C', '2018-02'],
#  ['Kerns', 'Daniel', 'Exam C', '2018-02'],
#  ['Kerns', 'Matt', 'Exam C', '2018-02'],
#  ['Keung', 'Ying Chun Michael', 'Exam C', '2018-02'],
#  ['Kewalin', 'Krittapat', 'Exam C', '2018-02'],
#  ['Kezwer', 'Jason Travis', 'Exam C', '2018-02'],
#  ['Khalil', 'Arif', 'Exam C', '2018-02'],
#  ['Khan', 'Haris', 'Exam C', '2018-02'],
#  ['Khan', 'Kaylaah Paavana', 'Exam C', '2018-02'],
#  ['Khieu', 'Antony', 'Exam C', '2018-02'],
#  ['Kho', 'Leonard', 'Exam C', '2018-02'],
#  ['Khor', 'Boon Wei', 'Exam C', '2018-02'],
#  ['Kielb', 'Edward', 'Exam C', '2018-02'],
#  ['Kim', 'Bosong', 'Exam C', '2018-02'],
#  ['Kim', 'Ha Neul', 'Exam C', '2018-02'],
#  ['Kim', 'Heekyung', 'Exam C', '2018-02'],
#  ['Kim', 'Jane', 'Exam C', '2018-02'],
#  ['Kim', 'Jin', 'Exam C', '2018-02'],
#  ['Kim', 'Jin-Sook', 'Exam C', '2018-02'],
#  ['Kim', 'Kibeom', 'Exam C', '2018-02'],
#  ['Kim', 'Sanghoon', 'Exam C', '2018-02'],
#  ['Kim', 'Seohee', 'Exam C', '2018-02'],
#  ['Kim', 'Soo Jeung', 'Exam C', '2018-02'],
#  ['Kim', 'Tae Hyun', 'Exam C', '2018-02'],
#  ['Kim', 'Yongjin', 'Exam C', '2018-02'],
#  ['Kim', 'Young-Hyun', 'Exam C', '2018-02'],
#  ['Kim', 'Youngjei', 'Exam C', '2018-02'],
#  ['Kiriakopoulos', 'Konstantinos A', 'Exam C', '2018-02'],
#  ['Kirkland', 'Thomas', 'Exam C', '2018-02'],
#  ['Kishore', 'Vaibhav', 'Exam C', '2018-02'],
#  ['Klingenberg', 'Kelsie A', 'Exam C', '2018-02'],
#  ['Knoles', 'Mykel', 'Exam C', '2018-02'],
#  ['Koesling', 'Kyle', 'Exam C', '2018-02'],
#  ['Kok', 'Ronald Kai Jeat', 'Exam C', '2018-02'],
#  ['Kokic', 'Amina', 'Exam C', '2018-02'],
#  ['Kolandjian', 'Shaghig', 'Exam C', '2018-02'],
#  ['Kong', 'Shuangshuang', 'Exam C', '2018-02'],
#  ['Koo', 'Jian Wei', 'Exam C', '2018-02'],
#  ['Kornack', 'David', 'Exam C', '2018-02'],
#  ['Kramer', 'Kaitlyn A.', 'Exam C', '2018-02'],
#  ['Krines', 'Mark Anthony', 'Exam C', '2018-02'],
#  ['Krishnamurthy', 'Vyas', 'Exam C', '2018-02'],
#  ['Krochmalski', 'Matthew William', 'Exam C', '2018-02'],
#  ['Krzanowski', 'Michael Edward', 'Exam C', '2018-02'],
#  ['Kuan', 'Man Huen', 'Exam C', '2018-02'],
#  ['Kulas', 'Jamie', 'Exam C', '2018-02'],
#  ['Kulczak', 'Matthew', 'Exam C', '2018-02'],
#  ['Kumhangphon', 'Teerakan', 'Exam C', '2018-02'],
#  ['Kunz', 'Brady', 'Exam C', '2018-02'],
#  ['Kuo', 'Kungchao', 'Exam C', '2018-02'],
#  ['Kwak', 'Ingyu', 'Exam C', '2018-02'],
#  ['Kwan', 'Michael Ho Wan', 'Exam C', '2018-02'],
#  ['Kwok', 'Man Kit', 'Exam C', '2018-02'],
#  ['Kwon', 'Oh Ryoun', 'Exam C', '2018-02'],
#  ['La Russo', 'Will', 'Exam C', '2018-02'],
#  ['LaBrosse', 'Laura', 'Exam C', '2018-02'],
#  ['LaCara', 'Jennifer', 'Exam C', '2018-02'],
#  ['LaCroix', 'Katlyn', 'Exam C', '2018-02'],
#  ['Lafser', 'Thomas', 'Exam C', '2018-02'],
#  ['Lai', 'Chao-An', 'Exam C', '2018-02'],
#  ['Lai', 'Ching Yi', 'Exam C', '2018-02'],
#  ['Lai', 'Chun Hin', 'Exam C', '2018-02'],
#  ['Lalia', 'Ramanjit Singh', 'Exam C', '2018-02'],
#  ['Lam', 'Chi Wing', 'Exam C', '2018-02'],
#  ['Lam', 'Chun Yin', 'Exam C', '2018-02'],
#  ['Lam', 'Jorden', 'Exam C', '2018-02'],
#  ['Lam', 'Kin Wang', 'Exam C', '2018-02'],
#  ['Lambert', 'John Isaac', 'Exam C', '2018-02'],
#  ['Lamontagne', 'Alex', 'Exam C', '2018-02'],
#  ['Lamoureux', 'Eugenie', 'Exam C', '2018-02'],
#  ['Lan', 'Yu-Peng', 'Exam C', '2018-02'],
#  ['Landrigan', 'David A', 'Exam C', '2018-02'],
#  ['Lang', 'Erin', 'Exam C', '2018-02'],
#  ['Lapierre', 'Brian', 'Exam C', '2018-02'],
#  ['Lapkiewicz', 'Ellen', 'Exam C', '2018-02'],
#  ['Larade', 'Michel', 'Exam C', '2018-02'],
#  ['LaRiccia', 'Dante', 'Exam C', '2018-02'],
#  ['LaRock', 'Mason Michael', 'Exam C', '2018-02'],
#  ['Lathigra', 'Ravin Tushar', 'Exam C', '2018-02'],
#  ['Lathigra', 'Taran', 'Exam C', '2018-02'],
#  ['La-Trinh', 'Jennie', 'Exam C', '2018-02'],
#  ['Lauer', 'Lauren Michele', 'Exam C', '2018-02'],
#  ['Lavella', 'Allison', 'Exam C', '2018-02'],
#  ['Law', 'Cheuk Kwan', 'Exam C', '2018-02'],
#  ['Lawrenson', 'Christopher', 'Exam C', '2018-02'],
#  ['Le Dong', 'Tuan Anh', 'Exam C', '2018-02'],
#  ['Le', 'Quyen', 'Exam C', '2018-02'],
#  ['Lebeuf', 'David', 'Exam C', '2018-02'],
#  ['Leduc', 'Marie-Michelle', 'Exam C', '2018-02'],
#  ['Lee', 'Agatha', 'Exam C', '2018-02'],
#  ['Lee', 'Dain', 'Exam C', '2018-02'],
#  ['Lee', 'Eungkyong', 'Exam C', '2018-02'],
#  ['Lee', 'Eunju', 'Exam C', '2018-02'],
#  ['Lee', 'Eunkyung', 'Exam C', '2018-02'],
#  ['Lee', 'Hye Jin', 'Exam C', '2018-02'],
#  ['Lee', 'Jaehyung', 'Exam C', '2018-02'],
#  ['Lee', 'Jessica', 'Exam C', '2018-02'],
#  ['Lee', 'Kyunghyun', 'Exam C', '2018-02'],
#  ['Lee', 'Sang Jun', 'Exam C', '2018-02'],
#  ['Lee', 'Sangsoo', 'Exam C', '2018-02'],
#  ['Lee', 'Sarah', 'Exam C', '2018-02'],
#  ['Lee', 'Sunmin', 'Exam C', '2018-02'],
#  ['Lee', 'Wing Tung', 'Exam C', '2018-02'],
#  ['Lee', 'Yin Pok Robert', 'Exam C', '2018-02'],
#  ['Lee', 'Yu Tung', 'Exam C', '2018-02'],
#  ['Lee', 'Yunji', 'Exam C', '2018-02'],
#  ['Lehtonen', 'Pierce', 'Exam C', '2018-02'],
#  ['Lépine', 'Kaesey-Andrew', 'Exam C', '2018-02'],
#  ['Leung', 'Caughlin George', 'Exam C', '2018-02'],
#  ['Leung', 'Ching Fung', 'Exam C', '2018-02'],
#  ['Leung', 'King Sang', 'Exam C', '2018-02'],
#  ['Leung', 'Lok Lam', 'Exam C', '2018-02'],
#  ['Leung', 'Tung Yin', 'Exam C', '2018-02'],
#  ['Leung', 'Yik Kan Chester', 'Exam C', '2018-02'],
#  ['Leurquin', 'Jason', 'Exam C', '2018-02'],
#  ['Levine', 'Apple', 'Exam C', '2018-02'],
#  ['Levitt', 'Caroline Alexis', 'Exam C', '2018-02'],
#  ['Lew', 'Zachary', 'Exam C', '2018-02'],
#  ['Li', 'Chao Qi', 'Exam C', '2018-02'],
#  ['Li', 'Chi-Hao', 'Exam C', '2018-02'],
#  ['Li', 'Gartim', 'Exam C', '2018-02'],
#  ['Li', 'Haiyan', 'Exam C', '2018-02'],
#  ['Li', 'Honglin', 'Exam C', '2018-02'],
#  ['Li', 'Hua', 'Exam C', '2018-02'],
#  ['Li', 'Jiahong', 'Exam C', '2018-02'],
#  ['Li', 'Jiajin', 'Exam C', '2018-02'],
#  ['Li', 'Jinghui', 'Exam C', '2018-02'],
#  ['Li', 'Mingwei', 'Exam C', '2018-02'],
#  ['Li', 'Mingxi', 'Exam C', '2018-02'],
#  ['Li', 'Qi', 'Exam C', '2018-02'],
#  ['Li', 'Qiankun', 'Exam C', '2018-02'],
#  ['Li', 'Qianlei', 'Exam C', '2018-02'],
#  ['Li', 'Qixuan', 'Exam C', '2018-02'],
#  ['Li', 'Shushangxuan', 'Exam C', '2018-02'],
#  ['Li', 'Stephanie', 'Exam C', '2018-02'],
#  ['Li', 'Tianjiao', 'Exam C', '2018-02'],
#  ['Li', 'Wei', 'Exam C', '2018-02'],
#  ['Li', 'Xiaochen', 'Exam C', '2018-02'],
#  ['Li', 'Yangyang', 'Exam C', '2018-02'],
#  ['Li', 'Yanli', 'Exam C', '2018-02'],
#  ['Li', 'Yuewen', 'Exam C', '2018-02'],
#  ['Li', 'Yuying', 'Exam C', '2018-02'],
#  ['Lian', 'Sining', 'Exam C', '2018-02'],
#  ['Liang', 'Alan', 'Exam C', '2018-02'],
#  ['Liang', 'Kailin', 'Exam C', '2018-02'],
#  ['Liang', 'Zhangqi', 'Exam C', '2018-02'],
#  ['Liao', 'Xiaoqiao', 'Exam C', '2018-02'],
#  ['Lidsky', 'Sara B.', 'Exam C', '2018-02'],
#  ['Lie', 'Michael', 'Exam C', '2018-02'],
#  ['Lim', 'Darren Yiren', 'Exam C', '2018-02'],
#  ['Lim', 'Pei Ling', 'Exam C', '2018-02'],
#  ['Lim', 'Rhyxian', 'Exam C', '2018-02'],
#  ['Lim', 'Shu Yi', 'Exam C', '2018-02'],
#  ['Lim', 'Ying Sing', 'Exam C', '2018-02'],
#  ['Lim', 'Zi Yong', 'Exam C', '2018-02'],
#  ['Lin', 'Chengyang', 'Exam C', '2018-02'],
#  ['Lin', 'Chun Man', 'Exam C', '2018-02'],
#  ['Lin', 'Daniel', 'Exam C', '2018-02'],
#  ['Lin', 'Mingshen', 'Exam C', '2018-02'],
#  ['Lin', 'Ting', 'Exam C', '2018-02'],
#  ['Lin', 'Yau Yin', 'Exam C', '2018-02'],
#  ['Linardi', 'Matthew Francis', 'Exam C', '2018-02'],
#  ['Lindholm', 'Ana Joy Mikkelson', 'Exam C', '2018-02'],
#  ['Link', 'Emily Jane', 'Exam C', '2018-02'],
#  ['Liston', 'Timothy Nicholas', 'Exam C', '2018-02'],
#  ['Liu', 'Charles', 'Exam C', '2018-02'],
#  ['Liu', 'Dong-Hao', 'Exam C', '2018-02'],
#  ['Liu', 'Dongmei', 'Exam C', '2018-02'],
#  ['Liu', 'Feiying', 'Exam C', '2018-02'],
#  ['Liu', 'Guorui', 'Exam C', '2018-02'],
#  ['Liu', 'Hao', 'Exam C', '2018-02'],
#  ['Liu', 'Ho-Min', 'Exam C', '2018-02'],
#  ['Liu', 'Junyan', 'Exam C', '2018-02'],
#  ['Liu', 'Mingyue', 'Exam C', '2018-02'],
#  ['Liu', 'Min-Jui', 'Exam C', '2018-02'],
#  ['Liu', 'Nan', 'Exam C', '2018-02'],
#  ['Liu', 'Siti', 'Exam C', '2018-02'],
#  ['Liu', 'Xiaohang', 'Exam C', '2018-02'],
#  ['Liu', 'Xiaoxu', 'Exam C', '2018-02'],
#  ['Liu', 'Xiaoxuan', 'Exam C', '2018-02'],
#  ['Liu', 'Yihan', 'Exam C', '2018-02'],
#  ['Liu', 'Yu', 'Exam C', '2018-02'],
#  ['Liu', 'Yun Chen', 'Exam C', '2018-02'],
#  ['Lo', 'See Chai', 'Exam C', '2018-02'],
#  ['Lok', 'Chi Kit', 'Exam C', '2018-02'],
#  ['Loke', 'Sien Son', 'Exam C', '2018-02'],
#  ['Lonergan', 'Scott', 'Exam C', '2018-02'],
#  ['Long', 'Kristen', 'Exam C', '2018-02'],
#  ['Lonsdale', 'Chris', 'Exam C', '2018-02'],
#  ['Loo', 'Chun Wai', 'Exam C', '2018-02'],
#  ['Lore', 'Andrew C', 'Exam C', '2018-02'],
#  ['Loscerbo', 'Alexander', 'Exam C', '2018-02'],
#  ['Low', 'Kevin Ito', 'Exam C', '2018-02'],
#  ['Lowe', 'Stephanie', 'Exam C', '2018-02'],
#  ['Lu', 'Crystal', 'Exam C', '2018-02'],
#  ['Lu', 'Yijia', 'Exam C', '2018-02'],
#  ['Lu', 'Zhaoyu', 'Exam C', '2018-02'],
#  ['Lucero', 'Anthony Stephen', 'Exam C', '2018-02'],
#  ['Luckenbaugh', 'Justin T', 'Exam C', '2018-02'],
#  ['Luk', 'Kwong Wa', 'Exam C', '2018-02'],
#  ['Luke', 'Nathaniel', 'Exam C', '2018-02'],
#  ['Lum', 'Bryanna', 'Exam C', '2018-02'],
#  ['Luo', 'Mengjin', 'Exam C', '2018-02'],
#  ['Lutz', 'Alexander Leighton', 'Exam C', '2018-02'],
#  ['Lutzak', 'Meredith', 'Exam C', '2018-02'],
#  ['Ma', 'Liyun', 'Exam C', '2018-02'],
#  ['Ma', 'Xiaoang', 'Exam C', '2018-02'],
#  ['Mace', 'Susan', 'Exam C', '2018-02'],
#  ['MacKeen', 'Joshua', 'Exam C', '2018-02'],
#  ['Madden', 'Rachel', 'Exam C', '2018-02'],
#  ['Mainville', 'Clément-Olivier', 'Exam C', '2018-02'],
#  ['Mak', 'Chee Lai', 'Exam C', '2018-02'],
#  ['Mak', 'Herrick', 'Exam C', '2018-02'],
#  ['Mananghaya', 'Frances Mae', 'Exam C', '2018-02'],
#  ['Mangiardi', 'Caroline Marie', 'Exam C', '2018-02'],
#  ['Manley', 'John', 'Exam C', '2018-02'],
#  ['Mannem', 'Kapil Reddy', 'Exam C', '2018-02'],
#  ['Mao', 'Yanjing', 'Exam C', '2018-02'],
#  ['March', 'Rachel', 'Exam C', '2018-02'],
#  ['Marchese', 'Sarah Ann', 'Exam C', '2018-02'],
#  ['Marcinkowski', 'Kevin Matthew', 'Exam C', '2018-02'],
#  ['Marino', 'Sydney', 'Exam C', '2018-02'],
#  ['Mark', 'Adam Louis', 'Exam C', '2018-02'],
#  ['Marshall', 'Kristen', 'Exam C', '2018-02'],
#  ['Marthin', 'Tiffany', 'Exam C', '2018-02'],
#  ['Martin', 'Catherine', 'Exam C', '2018-02'],
#  ['Martínez Téllez', 'José Enrique', 'Exam C', '2018-02'],
#  ['Matherley', 'James Harvey', 'Exam C', '2018-02'],
#  ['Mattison', 'Laura', 'Exam C', '2018-02'],
#  ['Maxwell', 'Nathan Lee', 'Exam C', '2018-02'],
#  ['McClone', 'Andrew Ryan', 'Exam C', '2018-02'],
#  ['McCormick', 'Amanda', 'Exam C', '2018-02'],
#  ['McDonough', 'Matthew', 'Exam C', '2018-02'],
#  ['McGrath', 'Liam', 'Exam C', '2018-02'],
#  ['McKeown', 'Katherine', 'Exam C', '2018-02'],
#  ['McSwiggan', 'Padraic', 'Exam C', '2018-02'],
#  ['McVay', 'Charles D', 'Exam C', '2018-02'],
#  ['Mebarek', 'Sofiane', 'Exam C', '2018-02'],
#  ['Mele', 'Anthony', 'Exam C', '2018-02'],
#  ['Melville', 'Kevin', 'Exam C', '2018-02'],
#  ['Meng', 'Ke', 'Exam C', '2018-02'],
#  ['Mercer', 'Sean P', 'Exam C', '2018-02'],
#  ['Meredith', 'John A', 'Exam C', '2018-02'],
#  ['Meunier', 'Alexandre', 'Exam C', '2018-02'],
#  ['Michaud', 'Kurtis', 'Exam C', '2018-02'],
#  ['Mierl', 'Hayden Henry', 'Exam C', '2018-02'],
#  ['Miley', 'Lawrence', 'Exam C', '2018-02'],
#  ['Miller', 'Raleigh Rebecca', 'Exam C', '2018-02'],
#  ['Millstine', 'Erik Joseph', 'Exam C', '2018-02'],
#  ['Min', 'Sun Woo', 'Exam C', '2018-02'],
#  ['Mirchandani', 'Harsha', 'Exam C', '2018-02'],
#  ['Modjo', 'Felix', 'Exam C', '2018-02'],
#  ['Mok Tsze Chung', 'Elodie Rachel', 'Exam C', '2018-02'],
#  ['Mok', 'Kar Khin', 'Exam C', '2018-02'],
#  ['Momin', 'Tashmina Z', 'Exam C', '2018-02'],
#  ['Montreewat', 'Rati', 'Exam C', '2018-02'],
#  ['Moon', 'Whidam', 'Exam C', '2018-02'],
#  ['Morin', 'Isabelle', 'Exam C', '2018-02'],
#  ['Morissette', 'William', 'Exam C', '2018-02'],
#  ['Morosan', 'Maria', 'Exam C', '2018-02'],
#  ['Muckenhirn', 'Daniel William', 'Exam C', '2018-02'],
#  ['Muelleman', 'Andrew', 'Exam C', '2018-02'],
#  ['Muliawan', 'Dylan Christopher', 'Exam C', '2018-02'],
#  ['Mun Wei', 'Lim', 'Exam C', '2018-02'],
#  ['Munroe', 'Taylor', 'Exam C', '2018-02'],
#  ['Murphy', 'Christopher Hatcher', 'Exam C', '2018-02'],
#  ['Murphy', 'Christopher J', 'Exam C', '2018-02'],
#  ['Murphy', 'John Bradley', 'Exam C', '2018-02'],
#  ['Murphy', 'Kim Marie', 'Exam C', '2018-02'],
#  ['Murphy', 'Max T.', 'Exam C', '2018-02'],
#  ['Murray', 'Matthew', 'Exam C', '2018-02'],
#  ['Mutagaywa', 'Evelyn Vanessa', 'Exam C', '2018-02'],
#  ['Myung Yoon', 'Lee', 'Exam C', '2018-02'],
#  ['Naess-Olivier', 'Maxime', 'Exam C', '2018-02'],
#  ['Naftali', 'William', 'Exam C', '2018-02'],
#  ['Navaratnam', 'Thenosh', 'Exam C', '2018-02'],
#  ['Nelson', 'Shyanne', 'Exam C', '2018-02'],
#  ['Nemerofsky', 'Stephanie L', 'Exam C', '2018-02'],
#  ['Neo', 'Shun Yi', 'Exam C', '2018-02'],
#  ['Nesterov', 'Timour', 'Exam C', '2018-02'],
#  ['Ng', 'Guan Jie', 'Exam C', '2018-02'],
#  ['Ng', 'Ka Yin', 'Exam C', '2018-02'],
#  ['Ng', 'Ming-Zhou', 'Exam C', '2018-02'],
#  ['Ng', 'Natalie', 'Exam C', '2018-02'],
#  ['Ng', 'Wei Qi', 'Exam C', '2018-02'],
#  ['Ngo', 'William', 'Exam C', '2018-02'],
#  ['Nguyen', 'Hang', 'Exam C', '2018-02'],
#  ['Nguyen', 'Quoc Anh', 'Exam C', '2018-02'],
#  ['Ni', 'Mengyao', 'Exam C', '2018-02'],
#  ['Nichols', 'Marlee Elizabeth', 'Exam C', '2018-02'],
#  ['Nieh', 'Ruth Chia-En', 'Exam C', '2018-02'],
#  ['Nilsson', 'Kris', 'Exam C', '2018-02'],
#  ['Ning', 'Xiaofu', 'Exam C', '2018-02'],
#  ['Niu', 'Beihan', 'Exam C', '2018-02'],
#  ['Nolan', 'Daniel G', 'Exam C', '2018-02'],
#  ['Norell', 'Kathleen Victoria', 'Exam C', '2018-02'],
#  ['Norman', 'Thomas', 'Exam C', '2018-02'],
#  ['Nuehring', 'Larry', 'Exam C', '2018-02'],
#  ['Obin', 'Michael', 'Exam C', '2018-02'],
#  ["O'Brien", 'Timothy Rock', 'Exam C', '2018-02'],
#  ['Odum', 'Matthew', 'Exam C', '2018-02'],
#  ['Oluwafemi', 'Fadiran', 'Exam C', '2018-02'],
#  ['Omondi', 'John Paul Okoth', 'Exam C', '2018-02'],
#  ['Oneal', 'Joseph Vincent', 'Exam C', '2018-02'],
#  ['Or', 'Florina', 'Exam C', '2018-02'],
#  ['Ormiston', 'Ashley Megan', 'Exam C', '2018-02'],
#  ['Ortiz', 'Yannick', 'Exam C', '2018-02'],
#  ['Osadon', 'Leeat', 'Exam C', '2018-02'],
#  ['Osman', 'Abdallah', 'Exam C', '2018-02'],
#  ['Otter', 'Jordan', 'Exam C', '2018-02'],
#  ['Ouedraogo', 'Irmeya Ismael', 'Exam C', '2018-02'],
#  ['Pack', 'Jeremiah', 'Exam C', '2018-02'],
#  ['Paczko', 'Thomas H', 'Exam C', '2018-02'],
#  ['Pagé', 'Thomas', 'Exam C', '2018-02'],
#  ['Palankar', 'Rashmi', 'Exam C', '2018-02'],
#  ['Palmer', 'Nicholas James', 'Exam C', '2018-02'],
#  ['Pan', 'Ziyin', 'Exam C', '2018-02'],
#  ['Pang', 'Kwok Chu', 'Exam C', '2018-02'],
#  ['Panni', 'Xie', 'Exam C', '2018-02'],
#  ['Paparelli', 'Joseph Frank', 'Exam C', '2018-02'],
#  ['Park', 'Garam', 'Exam C', '2018-02'],
#  ['Park', 'Geonchoon', 'Exam C', '2018-02'],
#  ['Park', 'Gyujin', 'Exam C', '2018-02'],
#  ['Park', 'Jaehyeon', 'Exam C', '2018-02'],
#  ['Park', 'Joonyeon', 'Exam C', '2018-02'],
#  ['Park', 'Suhyeon', 'Exam C', '2018-02'],
#  ['Park', 'Sunghee', 'Exam C', '2018-02'],
#  ['Parkinson', 'Brian Stephen', 'Exam C', '2018-02'],
#  ['Parla', 'Christopher', 'Exam C', '2018-02'],
#  ['Patterson', 'Robert Donald II', 'Exam C', '2018-02'],
#  ['Pawarat', 'Songpol', 'Exam C', '2018-02'],
#  ['Pedersen', 'Kaitlyn Rose', 'Exam C', '2018-02'],
#  ['Peng', 'Jiao', 'Exam C', '2018-02'],
#  ['Perhac', 'Alexander', 'Exam C', '2018-02'],
#  ['Perkins', 'Christopher Charles', 'Exam C', '2018-02'],
#  ['Perreault-Turmel', 'Emmy', 'Exam C', '2018-02'],
#  ['Persaud', 'Vijay Tanveer', 'Exam C', '2018-02'],
#  ['Persico', 'Anthony', 'Exam C', '2018-02'],
#  ['Peters', 'Ryan James', 'Exam C', '2018-02'],
#  ['Peterson', 'Michael Douglas', 'Exam C', '2018-02'],
#  ['Phillips', 'Robin', 'Exam C', '2018-02'],
#  ['Phua', 'Cheng En', 'Exam C', '2018-02'],
#  ['Piehl', 'Tyler', 'Exam C', '2018-02'],
#  ['Pieroni', 'Sean Adam', 'Exam C', '2018-02'],
#  ['Pikul', 'Stanley Joseph', 'Exam C', '2018-02'],
#  ['Pinet-Forcier', 'Mariane', 'Exam C', '2018-02'],
#  ['Pirkle', 'Robert', 'Exam C', '2018-02'],
#  ['Piscitello', 'Amanda', 'Exam C', '2018-02'],
#  ['Pittard', 'Matthew', 'Exam C', '2018-02'],
#  ['Pizzuto', 'Brent Alexander', 'Exam C', '2018-02'],
#  ['Plunkitt', 'Liam', 'Exam C', '2018-02'],
#  ['Pogrebinsky', 'Alexander', 'Exam C', '2018-02'],
#  ['Popplewell', 'Aiesha Marian Chloe', 'Exam C', '2018-02'],
#  ['Portuese', 'Lawrence Ignatius', 'Exam C', '2018-02'],
#  ['Post', 'Michelle Nicole', 'Exam C', '2018-02'],
#  ['Powell', 'Justine', 'Exam C', '2018-02'],
#  ['Pradhan', 'Azhar Nooruddin', 'Exam C', '2018-02'],
#  ['Preskill', 'Gabriel Asher', 'Exam C', '2018-02'],
#  ['Pu', 'Yao', 'Exam C', '2018-02'],
#  ['Pudlowski', 'Eric Matthew', 'Exam C', '2018-02'],
#  ['Pun', 'Ho Fai', 'Exam C', '2018-02'],
#  ['Qian', 'Bohong', 'Exam C', '2018-02'],
#  ['Qiao', 'Yuanfang', 'Exam C', '2018-02'],
#  ['Qin', 'Yuting', 'Exam C', '2018-02'],
#  ['Qiu', 'Di', 'Exam C', '2018-02'],
#  ['Qiu', 'Fangzhou', 'Exam C', '2018-02'],
#  ['Qu', 'Hanzhao', 'Exam C', '2018-02'],
#  ['Raeder', 'Michael', 'Exam C', '2018-02'],
#  ['Raibley', 'Benjamin', 'Exam C', '2018-02'],
#  ['Raja Hamzah', 'Raja Fara Athirah', 'Exam C', '2018-02'],
#  ['Rajbhandari', 'Alisha', 'Exam C', '2018-02'],
#  ['Ramlogan', 'Prianka', 'Exam C', '2018-02'],
#  ['Rao', 'Ziwei', 'Exam C', '2018-02'],
#  ['Raoof', 'Nadia', 'Exam C', '2018-02'],
#  ['Read', 'Alex Kevin', 'Exam C', '2018-02'],
#  ['Reading', 'Katherine Anne', 'Exam C', '2018-02'],
#  ['Ren', 'Yuexuan', 'Exam C', '2018-02'],
#  ['Renaud', 'Vincent', 'Exam C', '2018-02'],
#  ['Renth', 'Samantha', 'Exam C', '2018-02'],
#  ['Reusz', 'Dan Patrick', 'Exam C', '2018-02'],
#  ['Reyes', 'Paollo Deo', 'Exam C', '2018-02'],
#  ['Richard', 'Margaret Ann Rose', 'Exam C', '2018-02'],
#  ['Richards', 'Harrison Arend', 'Exam C', '2018-02'],
#  ['Richardson', 'Bradford II,', 'Exam C', '2018-02'],
#  ['Richert', 'Jaclyn Suzanne', 'Exam C', '2018-02'],
#  ['Riley', 'Shea', 'Exam C', '2018-02'],
#  ['Rim', 'Jaejun', 'Exam C', '2018-02'],
#  ['Robinson', 'Benjamin', 'Exam C', '2018-02'],
#  ['Robinson', 'Charlie', 'Exam C', '2018-02'],
#  ['Robinson', 'Kristen', 'Exam C', '2018-02'],
#  ['Rodberg', 'Brianna Leigh', 'Exam C', '2018-02'],
#  ['Rodríguez Bernier', 'Ubaldo', 'Exam C', '2018-02'],
#  ['Rodriguez', 'Renny', 'Exam C', '2018-02'],
#  ['Rogoz', 'Hanna Corynn', 'Exam C', '2018-02'],
#  ['Roh', 'Taehoon', 'Exam C', '2018-02'],
#  ['Romany-Ottley', 'Cowayne Clifton', 'Exam C', '2018-02'],
#  ['Ross', 'Hunter', 'Exam C', '2018-02'],
#  ['Roy', 'Jérémy', 'Exam C', '2018-02'],
#  ['Ruan', 'Zixin', 'Exam C', '2018-02'],
#  ['Rubin', 'Benjamin', 'Exam C', '2018-02'],
#  ['Rubin', 'Jaclyn A', 'Exam C', '2018-02'],
#  ['Rubin', 'Janet A', 'Exam C', '2018-02'],
#  ['Russell', 'Ryan Craig', 'Exam C', '2018-02'],
#  ['Russo', 'Tara', 'Exam C', '2018-02'],
#  ['Ryu', 'Benjamin', 'Exam C', '2018-02'],
#  ['Ryu', 'Young Seok', 'Exam C', '2018-02'],
#  ['Salazar Gomez', 'July Andrea', 'Exam C', '2018-02'],
#  ['Saleh', 'Bahaa Houssam', 'Exam C', '2018-02'],
#  ['Salgado Dos Santos', 'Gabriela Teresa', 'Exam C', '2018-02'],
#  ['Saltzman', 'Corinne', 'Exam C', '2018-02'],
#  ['Sanderell', 'Phillip', 'Exam C', '2018-02'],
#  ['Sanders', 'Brooke', 'Exam C', '2018-02'],
#  ['Sanders', 'Monty Clinton', 'Exam C', '2018-02'],
#  ['Sangho', 'Park', 'Exam C', '2018-02'],
#  ['Sangpornsuk', 'Nipit', 'Exam C', '2018-02'],
#  ['Santhakumar', 'Leon', 'Exam C', '2018-02'],
#  ['Sarza', 'Brittany', 'Exam C', '2018-02'],
#  ['Saunders', 'Curtis', 'Exam C', '2018-02'],
#  ['Sauseda', 'Christopher Michael', 'Exam C', '2018-02'],
#  ['Schlender', 'Allison', 'Exam C', '2018-02'],
#  ['Schlotter', 'Rebecca Lisa', 'Exam C', '2018-02'],
#  ['Schmitt', 'Joseph', 'Exam C', '2018-02'],
#  ['Schoenleber', 'Matthew William', 'Exam C', '2018-02'],
#  ['Schwartz', 'Jordan Marie', 'Exam C', '2018-02'],
#  ['Schwartz', 'William H.', 'Exam C', '2018-02'],
#  ['Scott', 'Braeleen Mary', 'Exam C', '2018-02'],
#  ['Seavers', 'Sean', 'Exam C', '2018-02'],
#  ['Seibler', 'Richard', 'Exam C', '2018-02'],
#  ['Sells', 'Anne', 'Exam C', '2018-02'],
#  ['Selvaratnam', 'Suganja', 'Exam C', '2018-02'],
#  ['Sempek', 'Michael', 'Exam C', '2018-02'],
#  ['Shaak', 'Rebecca', 'Exam C', '2018-02'],
#  ['Shah', 'Annoria Lynn', 'Exam C', '2018-02'],
#  ['Shaheen', 'Mohammad Ammar', 'Exam C', '2018-02'],
#  ['Shane', 'Hannah Lynn', 'Exam C', '2018-02'],
#  ['Sharrard', 'Dean James', 'Exam C', '2018-02'],
#  ['Shatto', 'Johnathan', 'Exam C', '2018-02'],
#  ['Shehata', 'Nour Maged', 'Exam C', '2018-02'],
#  ['Shelly', 'Stephen', 'Exam C', '2018-02'],
#  ['Shen', 'Likang', 'Exam C', '2018-02'],
#  ['Shen', 'Sirui', 'Exam C', '2018-02'],
#  ['Sheng', 'Tan Qi', 'Exam C', '2018-02'],
#  ['Sheng', 'Xue', 'Exam C', '2018-02'],
#  ['Sheth', 'Aadit', 'Exam C', '2018-02'],
#  ['Shi', 'Chuanyang', 'Exam C', '2018-02'],
#  ['Shi', 'Leyu', 'Exam C', '2018-02'],
#  ['Shi', 'Shang', 'Exam C', '2018-02'],
#  ['Shi', 'Zhouhao', 'Exam C', '2018-02'],
#  ['Shin', 'Joo Kyung', 'Exam C', '2018-02'],
#  ['Shin', 'Sukju', 'Exam C', '2018-02'],
#  ['Shipps', 'Amber', 'Exam C', '2018-02'],
#  ['Siff', 'Judah', 'Exam C', '2018-02'],
#  ['Silberberg', 'Nechama', 'Exam C', '2018-02'],
#  ['Simonsen', 'Kelsey Roberta', 'Exam C', '2018-02'],
#  ['Sin', 'Daniel Lok Yin', 'Exam C', '2018-02'],
#  ['Singh', 'Sukh', 'Exam C', '2018-02'],
#  ['Sinha', 'Rohit', 'Exam C', '2018-02'],
#  ['Siperko', 'Jessica Harrang', 'Exam C', '2018-02'],
#  ['Sirico', 'Noelle', 'Exam C', '2018-02'],
#  ['Siripatsopon', 'Nut', 'Exam C', '2018-02'],
#  ['Siu', 'Chak Fung Jeff', 'Exam C', '2018-02'],
#  ['Skupny', 'Nathan Curtis', 'Exam C', '2018-02'],
#  ['Smith Epaul', 'Meghan', 'Exam C', '2018-02'],
#  ['Smith', 'Timothy Byron', 'Exam C', '2018-02'],
#  ['Snajder', 'Kathleen Marie', 'Exam C', '2018-02'],
#  ['Solanki', 'Aishwarya', 'Exam C', '2018-02'],
#  ['Somtua', 'Krittanut', 'Exam C', '2018-02'],
#  ['Song', 'Changyu', 'Exam C', '2018-02'],
#  ['Song', 'Seung Ki', 'Exam C', '2018-02'],
#  ['Song', 'Su Yong', 'Exam C', '2018-02'],
#  ['Soo', 'Qiao Ling', 'Exam C', '2018-02'],
#  ['Soon', 'Wearn Qian', 'Exam C', '2018-02'],
#  ['Sorensen', 'Andrew Joseph', 'Exam C', '2018-02'],
#  ['Sotiri', 'Julia', 'Exam C', '2018-02'],
#  ['Sottile', 'Alex', 'Exam C', '2018-02'],
#  ['Spargo', 'Brian', 'Exam C', '2018-02'],
#  ['Spector', 'Danielle Alyse', 'Exam C', '2018-02'],
#  ['Spitza', 'Sean P', 'Exam C', '2018-02'],
#  ['Sprouls', 'Tim', 'Exam C', '2018-02'],
#  ['Stavrow', 'Nicholas III,', 'Exam C', '2018-02'],
#  ['Steele', 'Elizabeth', 'Exam C', '2018-02'],
#  ['Stewart', 'Gregory', 'Exam C', '2018-02'],
#  ['Stewart', 'Shannon', 'Exam C', '2018-02'],
#  ['Stier', 'Eric', 'Exam C', '2018-02'],
#  ['Stofanak', 'Gregory', 'Exam C', '2018-02'],
#  ['Storseth', 'Colton Samuel', 'Exam C', '2018-02'],
#  ['Strilchuk', 'Christian', 'Exam C', '2018-02'],
#  ['Stroh', 'Brian', 'Exam C', '2018-02'],
#  ['Stuve', 'Alexandria', 'Exam C', '2018-02'],
#  ['Su', 'Eric Heng', 'Exam C', '2018-02'],
#  ['Su', 'Guoxin', 'Exam C', '2018-02'],
#  ['Sullivan', 'Holly Barbara', 'Exam C', '2018-02'],
#  ['Sullivan', 'Leighann', 'Exam C', '2018-02'],
#  ['Sun', 'Di Meng', 'Exam C', '2018-02'],
#  ['Sun', 'Jianzhi', 'Exam C', '2018-02'],
#  ['Sun', 'Xun', 'Exam C', '2018-02'],
#  ['Sutton', 'Melissa Marie', 'Exam C', '2018-02'],
#  ['Suzuki', 'Nobuyuki', 'Exam C', '2018-02'],
#  ['Tachovsky', 'Tara', 'Exam C', '2018-02'],
#  ['Takahashi', 'Yuya', 'Exam C', '2018-02'],
#  ['Tan Ai Wen', 'Vivian', 'Exam C', '2018-02'],
#  ['Tan', 'Jie Ling', 'Exam C', '2018-02'],
#  ['Tan', 'Jun Hao', 'Exam C', '2018-02'],
#  ['Tan', 'Shan Heng', 'Exam C', '2018-02'],
#  ['Tan', 'Vincent', 'Exam C', '2018-02'],
#  ['Tan', 'Zhi Zheng', 'Exam C', '2018-02'],
#  ['Tang', 'Brayden', 'Exam C', '2018-02'],
#  ['Tang', 'Sin Long Sharon', 'Exam C', '2018-02'],
#  ['Tang', 'Siyuan', 'Exam C', '2018-02'],
#  ['Tang', 'Yat Tin', 'Exam C', '2018-02'],
#  ['Tang', 'Zhaofeng', 'Exam C', '2018-02'],
#  ['Tanjung', 'Natasha Odelia', 'Exam C', '2018-02'],
#  ['Tao', 'Siyang', 'Exam C', '2018-02'],
#  ['Taylor', 'Jared', 'Exam C', '2018-02'],
#  ['Teachey', 'Christopher Aaron', 'Exam C', '2018-02'],
#  ['Tenuta', 'Mark', 'Exam C', '2018-02'],
#  ['Teo', 'Yun Hao', 'Exam C', '2018-02'],
#  ['Thimm', 'Ryan', 'Exam C', '2018-02'],
#  ['Thomas', 'Arthur Lee', 'Exam C', '2018-02'],
#  ['Thomas', 'Eric V', 'Exam C', '2018-02'],
#  ['Thurnheer', 'Kyla', 'Exam C', '2018-02'],
#  ['Tian', 'Jing', 'Exam C', '2018-02'],
#  ['Tobias', 'Jose Manuel Vallestero', 'Exam C', '2018-02'],
#  ['Tran', 'Anhtuan Nguyen', 'Exam C', '2018-02'],
#  ['Tran', 'Huong Thi Thu', 'Exam C', '2018-02'],
#  ['Tran', 'Thang', 'Exam C', '2018-02'],
#  ['Tran', 'Vinh Quang Ngoc', 'Exam C', '2018-02'],
#  ['Trottier', 'Karelle', 'Exam C', '2018-02'],
#  ['Trudel', 'Laurence', 'Exam C', '2018-02'],
#  ['Trudel', 'Marianne', 'Exam C', '2018-02'],
#  ['Tsukamoto', 'Masaya', 'Exam C', '2018-02'],
#  ['Tu', 'Yexin', 'Exam C', '2018-02'],
#  ['Tu', 'Yi-Pei', 'Exam C', '2018-02'],
#  ['Tung', 'Matthew', 'Exam C', '2018-02'],
#  ['Tung', 'Wai Teing', 'Exam C', '2018-02'],
#  ['Turk', 'Meredith Alexandra', 'Exam C', '2018-02'],
#  ['Turner', 'Sean', 'Exam C', '2018-02'],
#  ['Ullah', 'Fayez', 'Exam C', '2018-02'],
#  ['Urquilla', 'Erick Alejandro', 'Exam C', '2018-02'],
#  ['Vachon', 'Justin', 'Exam C', '2018-02'],
#  ['Vahora', 'Amin', 'Exam C', '2018-02'],
#  ['Valenti', 'Anthony Michael', 'Exam C', '2018-02'],
#  ['van Laarhoven', 'Anna', 'Exam C', '2018-02'],
#  ['Vandalov', 'Aleksandr Vladimir', 'Exam C', '2018-02'],
#  ['Velin', 'Jack Michael', 'Exam C', '2018-02'],
#  ['Vetsuypens', 'Kevin Franci', 'Exam C', '2018-02'],
#  ['Vetter', 'Mercedes Ann', 'Exam C', '2018-02'],
#  ['Villalpando', 'Sergio Nicholas', 'Exam C', '2018-02'],
#  ['Voigt', 'Josh Ryan', 'Exam C', '2018-02'],
#  ['Von Der Embse', 'Jonah', 'Exam C', '2018-02'],
#  ['von Korff', 'Connor', 'Exam C', '2018-02'],
#  ['Vorchheimer', 'Miriam', 'Exam C', '2018-02'],
#  ['Voyer', 'Marie', 'Exam C', '2018-02'],
#  ['Walker', 'Jevaun Anthony', 'Exam C', '2018-02'],
#  ['Wall', 'Andrew', 'Exam C', '2018-02'],
#  ['Walsh', 'Michael', 'Exam C', '2018-02'],
#  ['Wang', 'Anran', 'Exam C', '2018-02'],
#  ['Wang', 'Cong', 'Exam C', '2018-02'],
#  ['Wang', 'Ershi', 'Exam C', '2018-02'],
#  ['Wang', 'Ke', 'Exam C', '2018-02'],
#  ['Wang', 'Li', 'Exam C', '2018-02'],
#  ['Wang', 'Linjia', 'Exam C', '2018-02'],
#  ['Wang', 'Xinran', 'Exam C', '2018-02'],
#  ['Wang', 'Yifei', 'Exam C', '2018-02'],
#  [' Wang', 'Yimeng', 'Exam C', '2018-02'],
#  ...]

# %% [markdown]
# We convert this list of lists to a pandas data frame for analysis.

# %%
import pandas as pd
df = pd.DataFrame(allNames, columns = ['first', 'last', 'exam', 'date'])
df.groupby(['first','last'])['exam'].count().sort_values(ascending=False)
# Out:
# first           last
# Liu             Chang                    9
#                 Yang                     8
# Yen             Wen-Yuan                 6
# Zhao            Yuxin                    6
# Al Kahfi        Muhammad                 5
# Li              Xiang                    5
# Wang            Yuqing                   5
# Liu             Yixuan                   5
# Zhang           Xinyu                    5
# Lee             Jay-Hee                  5
# Sun             Tian                     5
# Kim             Jaehwi                   4
# Liu             Xinyu                    4
# Wu              Yue                      4
# Wang            Zijia                    4
# Lu              Yuyan                    4
# Rim             Jaejun                   4
# Liu             Chen                     4
# Wang            Qi                       4
# Lam             Nok Ki                   4
# Guo             Tianao                   4
# He              Weiyu                    4
# Li              Zheng                    4
# Park            Seokjong                 4
# Zhang           Ping                     4
# Tang            Yuxin                    4
# Wang            Ziyi                     4
# Park            Joonyeon                 4
# Kwon            Jonghyun                 4
# Hsieh           Cheng Han                4
#                                         ..
# Morrow          Noah                     1
# Moore           Valerie                  1
# Morrissey       Thomas Ryan              1
# Morris          Jeffrey                  1
#                 Courtney                 1
# Morphis         Max Alexander Maberly    1
# Morosan         Maria                    1
# Morjaria        Neel                     1
#                 Deep                     1
# Morissette      William                  1
#                 Remi                     1
# Morin           Mitchell Taylor          1
#                 Charles                  1
# Moriarity       Kimberly Anne            1
# Morgen          Taylor                   1
# Morgano         Megan                    1
# Morgan          Michael                  1
#                 Kent Owen                1
#                 David                    1
# Moreno Esponda  José Luis                1
#                 Jose Luis                1
# Moreno          Vanessa                  1
#                 Alyssa                   1
# Morency         Isabelle                 1
#                 Charles-Antoine          1
# Moreau          Francis                  1
# Morcheid        Ashley A                 1
# Morasse         Rachel                   1
# Moosa           Aly Wazir                1
#  Ab Manan       Muhd Azman Firdaus       1
# Name: exam, Length: 18155, dtype: int64
